# %% [markdown]
# ### Setup

# %%
from main_functions.utils import read_grid_search
import pandas as pd

# %% [markdown]
# ### Check results - Tsinghua Dataset

# %% [markdown]
# #### k-fold DFT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
dft_kfold = read_grid_search("results_v3/tsinghua_1_DFT_4_Sum_kfold_1")
dft_kfold.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 5116      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 6668      DFT     500          10     Sum   (0.2, 0.2)       1.0    0.100
# 2578      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 4         DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2142      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 462       DFT     500          10     Sum   (0.5, 0.5)       2.0    0.010
# 1180      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 2526      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 6501      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 2117      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 5116       0.5       3        2       1           1        (1, 8, 16, 4)
# ...

# %%
dft_kfold.shape[0]
# Out:
# 7878

# %%
print(dft_kfold.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 5116 &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.001 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt7 &          0.010 &           0.82 &  20.96 &   54220 \\
# 6668 &      DFT &     500 &          10 &     Sum &   (0.2, 0.2) &       1.0 &    0.100 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt8 &          0.004 &           0.82 &  21.06 &   54220 \\
# ...

# %%
dftmean_kfold1 = read_grid_search("results_v3/tsinghua_1_DFT_4_Mean_kfold_1")
dftmean_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 412       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 1996      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2658      DFT     500          10    Mean   (0.2, 0.2)       1.0    0.001
# 1529      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 2472      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 2024      DFT     500          10    Mean  (0.3, 0.15)       1.0    0.001
# 94        DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 1714      DFT     500          10    Mean   (0.6, 0.2)       1.0    0.100
# 309       DFT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 406       DFT     500          10    Mean  (0.3, 0.15)       1.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 412        0.5       2        1       1           1       (1, 16, 16, 4)
# ...

# %%
dftmean_kfold1.shape[0]
# Out:
# 3164

# %%
dftmax_kfold1 = read_grid_search("results_v3/tsinghua_1_DFT_4_Max_kfold_1")
dftmax_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2274      DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 1655      DFT     500          10     Max   (0.3, 0.5)       0.0    0.001
# 1859      DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 1359      DFT     500          10     Max   (0.6, 0.2)       1.0    0.100
# 3053      DFT     500          10     Max   (0.6, 0.2)       0.0    0.001
# 2394      DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 930       DFT     500          10     Max   (0.5, 0.5)       0.0    0.001
# 1676      DFT     500          10     Max   (0.2, 0.2)       0.0    0.100
# 1393      DFT     500          10     Max   (0.5, 0.5)       0.0    0.010
# 75        DFT     500          10     Max  (0.3, 0.15)       2.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2274       0.5       3        2       1           4        (1, 8, 16, 4)
# ...

# %%
dftmax_kfold1.shape[0]
# Out:
# 3092

# %% [markdown]
# ##### Subject 4

# %%
# taking abs(DHT(original signal))
dft_kfold4 = read_grid_search("results_v3/tsinghua_4_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6527      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 7433      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 1553      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 3110      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 994       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 4827      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 5989      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 1526      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 4753      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 6640      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6527       0.5       2        1       3           1       (1, 16, 16, 4)
# ...

# %%
dft_kfold4.shape[0]
# Out:
# 7878

# %%
print(dft_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 6527 &      DFT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.001 &       0.5 &       2 &        1 &       3 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.88 &  27.85 &  201092 \\
# 7433 &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.86 &  27.42 &   68356 \\
# ...

# %%
dftmean_kfold4 = read_grid_search("results_v3/tsinghua_4_DFT_4_Mean_kfold_1")
dftmean_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2121      DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 1674      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 2425      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.001
# 2722      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2002      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 1775      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 1769      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 2041      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.100
# 589       DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 1623      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2121       0.5       2        1       1           1         (1, 4, 8, 4)
# ...

# %%
dftmean_kfold4.shape[0]
# Out:
# 3164

# %%
dftmax_kfold4 = read_grid_search("results_v3/tsinghua_4_DFT_4_Max_kfold_1")
dftmax_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 1379      DFT     500          10     Max  (0.5, 0.5)       0.0     0.10
# 1051      DFT     500          10     Max  (0.6, 0.2)       2.0     0.10
# 2198      DFT     500          10     Max  (0.5, 0.5)       0.0     0.10
# 1853      DFT     500          10     Max  (0.6, 0.2)       1.0     0.10
# 2455      DFT     500          10     Max  (0.5, 0.5)       0.0     0.01
# 2791      DFT     500          10     Max  (0.5, 0.5)       0.0     0.10
# 721       DFT     500          10     Max  (0.5, 0.5)       0.0     0.01
# 2578      DFT     500          10     Max  (0.2, 0.2)       0.0     0.01
# 649       DFT     500          10     Max  (0.2, 0.2)       0.0     0.10
# 671       DFT     500          10     Max  (0.6, 0.2)       0.0     0.01
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1379       0.5       2        1       1           2       (1, 16, 16, 4)
# ...

# %%
dftmax_kfold4.shape[0]
# Out:
# 3092

# %% [markdown]
# ##### Subject 13

# %%
# taking abs(DHT(original signal))
dft_kfold13 = read_grid_search("results_v3/tsinghua_13_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6626      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.001
# 4063      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 3856      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 6545      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.010
# 3526      DFT     500          10     Sum   (0.2, 0.2)       2.0    0.010
# 6822      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 439       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2712      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 6204      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 4992      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6626       0.5       3        2       1           5       (1, 16, 16, 4)
# ...

# %%
dft_kfold13.shape[0]
# Out:
# 7878

# %%
print(dft_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 6626 &      DFT &     500 &          10 &     Sum &   (0.3, 0.5) &       2.0 &    0.001 &       0.5 &       3 &        2 &       1 &           5 &       (1, 16, 16, 4) &      opt8 &         0.0040 &           0.86 &  20.14 &   20756 \\
# 4063 &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &         0.0100 &           0.86 &  26.94 &   68356 \\
# ...

# %%
dftmean_kfold13 = read_grid_search("results_v3/tsinghua_13_DFT_4_Mean_kfold_1")
dftmean_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 3070      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 1714      DFT     500          10    Mean   (0.5, 0.5)       2.0    0.100
# 2378      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 1859      DFT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 2222      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 2314      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 2537      DFT     500          10    Mean  (0.3, 0.15)       1.0    0.001
# 497       DFT     500          10    Mean   (0.3, 0.5)       1.0    0.010
# 775       DFT     500          10    Mean  (0.3, 0.15)       1.0    0.001
# 892       DFT     500          10    Mean   (0.3, 0.5)       1.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 3070       0.5       3        2       3           5        (1, 8, 16, 4)
# ...

# %%
dftmean_kfold13.shape[0]
# Out:
# 3164

# %%
dftmax_kfold13 = read_grid_search("results_v3/tsinghua_13_DFT_4_Max_kfold_1")
dftmax_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1381      DFT     500          10     Max   (0.6, 0.2)       0.0    0.010
# 879       DFT     500          10     Max   (0.6, 0.2)       0.0    0.010
# 2570      DFT     500          10     Max   (0.3, 0.5)       2.0    0.100
# 1056      DFT     500          10     Max   (0.3, 0.5)       0.0    0.100
# 768       DFT     500          10     Max   (0.6, 0.2)       1.0    0.100
# 3075      DFT     500          10     Max   (0.3, 0.5)       0.0    0.001
# 276       DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 1526      DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 2107      DFT     500          10     Max   (0.5, 0.5)       0.0    0.010
# 1213      DFT     500          10     Max   (0.5, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1381       0.5       2        1       1           4         (1, 8, 8, 4)
# ...

# %%
dftmax_kfold13.shape[0]
# Out:
# 3092

# %% [markdown]
# ##### Subject 27

# %%
# taking abs(DHT(original signal))
dft_kfold27 = read_grid_search("results_v3/tsinghua_27_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 450       DFT     500          10     Sum   (0.2, 0.2)       0.0     0.10
# 339       DFT     500          10     Sum   (0.6, 0.2)       0.0     0.01
# 594       DFT     500          10     Sum   (0.2, 0.2)       0.0     0.01
# 5330      DFT     500          10     Sum   (0.5, 0.5)       0.0     0.10
# 1392      DFT     500          10     Sum   (0.2, 0.2)       0.0     0.10
# 7399      DFT     500          10     Sum   (0.3, 0.5)       0.0     0.10
# 3925      DFT     500          10     Sum   (0.5, 0.5)       0.0     0.10
# 4869      DFT     500          10     Sum   (0.2, 0.2)       0.0     0.10
# 4911      DFT     500          10     Sum  (0.3, 0.15)       0.0     0.01
# 7547      DFT     500          10     Sum   (0.6, 0.2)       0.0     0.10
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 450        0.5       3        2       3           1       (1, 16, 16, 4)
# ...

# %%
dft_kfold27.shape[0]
# Out:
# 7878

# %%
print(dft_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 450  &      DFT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &     0.10 &       0.5 &       3 &        2 &       3 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.96 &  20.47 &  303636 \\
# 339  &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &     0.01 &       0.5 &       2 &        1 &       1 &           1 &         (1, 8, 8, 4) &      opt4 &          0.010 &           0.90 &  28.12 &   36116 \\
# ...

# %%
dftmean_kfold27 = read_grid_search("results_v3/tsinghua_27_DFT_4_Mean_kfold_1")
dftmean_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 919       DFT     500          10    Mean   (0.2, 0.2)       0.0    0.010
# 703       DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 57        DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 1805      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 1801      DFT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 2973      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 2946      DFT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 2269      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 1310      DFT     500          10    Mean  (0.3, 0.15)       1.0    0.001
# 2084      DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 919        0.5       3        2       1           1       (1, 16, 16, 4)
# ...

# %%
dftmean_kfold27.shape[0]
# Out:
# 3164

# %%
dftmax_kfold27 = read_grid_search("results_v3/tsinghua_27_DFT_4_Max_kfold_1")
dftmax_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2411      DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 2322      DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 1083      DFT     500          10     Max  (0.3, 0.15)       2.0    0.010
# 2821      DFT     500          10     Max   (0.2, 0.2)       0.0    0.100
# 1206      DFT     500          10     Max   (0.6, 0.2)       0.0    0.001
# 250       DFT     500          10     Max  (0.3, 0.15)       2.0    0.010
# 989       DFT     500          10     Max   (0.2, 0.2)       2.0    0.001
# 1803      DFT     500          10     Max   (0.5, 0.5)       1.0    0.100
# 909       DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
# 914       DFT     500          10     Max   (0.3, 0.5)       2.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2411       0.5       3        2       1           3        (1, 8, 16, 4)
# ...

# %%
dftmax_kfold27.shape[0]
# Out:
# 3092

# %% [markdown]
# #### k-fold DHT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
# taking abs(DHT(original signal))
dht_kfold1 = read_grid_search("results_v3/tsinghua_1_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 5365      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.010
# 7578      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 6953      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.010
# 7134      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 2606      DHT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 4809      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.010
# 581       DHT     500          10     Sum  (0.2, 0.2)       0.0    0.010
# 1083      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.010
# 3027      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.001
# 2077      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 5365       0.5       3        2       1           1        (1, 8, 16, 4)
# ...

# %%
dht_kfold1.shape[0]
# Out:
# 7629

# %%
print(dht_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 5365 &      DHT &     500 &          10 &     Sum &  (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt7 &         0.0100 &           0.84 &  21.58 &   54220 \\
# 7578 &      DHT &     500 &          10 &     Sum &  (0.5, 0.5) &       0.0 &    0.001 &       0.5 &       3 &        2 &       1 &           1 &       (1, 16, 16, 4) &      opt3 &         0.0100 &           0.84 &  21.86 &  102356 \\
# ...

# %%
dhtmean_kfold1 = read_grid_search("results_v3/tsinghua_1_DHT_4_Mean_kfold_1")
dhtmean_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2852      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 2406      DHT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 3065      DHT     500          10    Mean   (0.5, 0.5)       1.0    0.010
# 2573      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 464       DHT     500          10    Mean   (0.3, 0.5)       1.0    0.010
# 1540      DHT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 2087      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 446       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 736       DHT     500          10    Mean   (0.2, 0.2)       2.0    0.100
# 2384      DHT     500          10    Mean  (0.3, 0.15)       1.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2852       0.5       3        2       1           1         (1, 8, 8, 4)
# ...

# %%
dhtmean_kfold1.shape[0]
# Out:
# 3167

# %%
dhtmax_kfold1 = read_grid_search("results_v3/tsinghua_1_DHT_4_Max_kfold_1")
dhtmax_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 684       DHT     500          10     Max  (0.3, 0.15)       0.0    0.010
# 1911      DHT     500          10     Max   (0.2, 0.2)       1.0    0.010
# 87        DHT     500          10     Max   (0.3, 0.5)       0.0    0.010
# 1153      DHT     500          10     Max   (0.6, 0.2)       0.0    0.001
# 22        DHT     500          10     Max   (0.5, 0.5)       0.0    0.010
# 1898      DHT     500          10     Max  (0.3, 0.15)       2.0    0.010
# 2804      DHT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 744       DHT     500          10     Max   (0.3, 0.5)       1.0    0.100
# 261       DHT     500          10     Max   (0.2, 0.2)       1.0    0.010
# 665       DHT     500          10     Max   (0.6, 0.2)       2.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 684        0.5       3        2       1           5       (1, 16, 16, 4)
# ...

# %%
dhtmax_kfold1.shape[0]
# Out:
# 3152

# %% [markdown]
# ##### Subject 4

# %%
# taking abs(DHT(original signal))
dht_kfold4 = read_grid_search("results_v3/tsinghua_4_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2282      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 3581      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 4394      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1452      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 2289      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 6372      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 4411      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 3765      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 4402      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 1591      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2282       0.5       2        1       1           4         (1, 8, 8, 4)
# ...

# %%
dht_kfold4.shape[0]
# Out:
# 7629

# %%
print(dht_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 2282 &      DHT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           4 &         (1, 8, 8, 4) &      opt4 &          0.010 &           0.84 &  27.34 &    9044 \\
# 3581 &      DHT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.100 &       0.5 &       2 &        1 &       3 &           2 &         (1, 4, 8, 4) &      opt8 &          0.010 &           0.84 &  27.34 &   28960 \\
# ...

# %%
dhtmean_kfold4 = read_grid_search("results_v3/tsinghua_4_DHT_4_Mean_kfold_1")
dhtmean_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1589      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2220      DHT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 2677      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 1567      DHT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 225       DHT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 838       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 1356      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 1831      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.010
# 2537      DHT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 2930      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1589       0.5       2        1       1           4         (1, 4, 8, 4)
# ...

# %%
dhtmean_kfold4.shape[0]
# Out:
# 3167

# %%
dhtmax_kfold4 = read_grid_search("results_v3/tsinghua_4_DHT_4_Max_kfold_1")
dhtmax_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2934      DHT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 958       DHT     500          10     Max   (0.6, 0.2)       2.0    0.010
# 2547      DHT     500          10     Max   (0.5, 0.5)       0.0    0.001
# 1813      DHT     500          10     Max   (0.6, 0.2)       1.0    0.010
# 888       DHT     500          10     Max  (0.3, 0.15)       0.0    0.010
# 1791      DHT     500          10     Max   (0.3, 0.5)       0.0    0.100
# 1669      DHT     500          10     Max   (0.3, 0.5)       0.0    0.010
# 1330      DHT     500          10     Max   (0.2, 0.2)       1.0    0.001
# 1490      DHT     500          10     Max   (0.6, 0.2)       1.0    0.100
# 2971      DHT     500          10     Max   (0.5, 0.5)       1.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2934       0.5       3        2       1           5         (1, 4, 8, 4)
# ...

# %%
dhtmax_kfold4.shape[0]
# Out:
# 3152

# %% [markdown]
# ##### Subject 13

# %%
# taking abs(DHT(original signal))
dht_kfold13 = read_grid_search("results_v3/tsinghua_13_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 4992      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 4727      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1914      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 3588      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 818       DHT     500          10     Sum   (0.6, 0.2)       2.0    0.100
# 6322      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 1513      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 1775      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 3724      DHT     500          10     Sum  (0.3, 0.15)       1.0    0.100
# 2656      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 4992       0.5       2        1       1           5       (1, 16, 16, 4)
# ...

# %%
dht_kfold13.shape[0]
# Out:
# 7628

# %%
print(dht_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 4992 &      DHT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.100 &       0.5 &       2 &        1 &       1 &           5 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.86 &  27.71 &   13956 \\
# 4727 &      DHT &     500 &          10 &     Sum &   (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       3 &        2 &       3 &           4 &         (1, 4, 8, 4) &      opt8 &          0.010 &           0.86 &  20.37 &   21280 \\
# ...

# %%
dhtmean_kfold13 = read_grid_search("results_v3/tsinghua_13_DHT_4_Mean_kfold_1")
dhtmean_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 656       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2010      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.010
# 2261      DHT     500          10    Mean   (0.5, 0.5)       0.0    0.010
# 646       DHT     500          10    Mean   (0.2, 0.2)       2.0    0.010
# 995       DHT     500          10    Mean   (0.2, 0.2)       2.0    0.100
# 3084      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 803       DHT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 2634      DHT     500          10    Mean   (0.3, 0.5)       2.0    0.100
# 209       DHT     500          10    Mean   (0.6, 0.2)       0.0    0.001
# 3101      DHT     500          10    Mean   (0.5, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 656        0.5       3        2       2           1       (1, 16, 16, 4)
# ...

# %%
dhtmean_kfold13.shape[0]
# Out:
# 3167

# %%
dhtmax_kfold13 = read_grid_search("results_v3/tsinghua_13_DHT_4_Max_kfold_1")
dhtmax_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 1014      DHT     500          10     Max  (0.3, 0.5)       0.0    0.010
# 907       DHT     500          10     Max  (0.5, 0.5)       0.0    0.010
# 588       DHT     500          10     Max  (0.6, 0.2)       0.0    0.010
# 3139      DHT     500          10     Max  (0.3, 0.5)       0.0    0.001
# 135       DHT     500          10     Max  (0.2, 0.2)       0.0    0.100
# 2054      DHT     500          10     Max  (0.6, 0.2)       0.0    0.100
# 2223      DHT     500          10     Max  (0.6, 0.2)       0.0    0.010
# 1911      DHT     500          10     Max  (0.5, 0.5)       0.0    0.010
# 2500      DHT     500          10     Max  (0.2, 0.2)       0.0    0.001
# 617       DHT     500          10     Max  (0.5, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1014       0.5       2        1       1           1        (1, 8, 16, 4)
# ...

# %%
dhtmax_kfold13.shape[0]
# Out:
# 3152

# %% [markdown]
# ##### Subject 27

# %%
# taking abs(DHT(original signal))
dht_kfold27 = read_grid_search("results_v3/tsinghua_27_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 315       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 2647      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 822       DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 775       DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 4953      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 7273      DHT     500          10     Sum  (0.3, 0.15)       1.0    0.100
# 7031      DHT     500          10     Sum   (0.5, 0.5)       1.0    0.100
# 1053      DHT     500          10     Sum   (0.5, 0.5)       1.0    0.001
# 4111      DHT     500          10     Sum   (0.6, 0.2)       2.0    0.001
# 5590      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 315        0.5       2        1       1           1       (1, 16, 16, 4)
# ...

# %%
dht_kfold27.shape[0]
# Out:
# 7628

# %%
print(dht_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 315  &      DHT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.100 &       0.5 &       2 &        1 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &         0.0100 &           0.94 &  26.79 &   68356 \\
# 2647 &      DHT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           2 &       (1, 16, 16, 4) &      opt8 &         0.0100 &           0.90 &  27.15 &   34356 \\
# ...

# %%
dhtmean_kfold27 = read_grid_search("results_v3/tsinghua_27_DHT_4_Mean_kfold_1")
dhtmean_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 504       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 1516      DHT     500          10    Mean   (0.6, 0.2)       0.0    0.001
# 303       DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 1886      DHT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 29        DHT     500          10    Mean   (0.5, 0.5)       0.0    0.100
# 829       DHT     500          10    Mean   (0.6, 0.2)       1.0    0.001
# 2245      DHT     500          10    Mean   (0.5, 0.5)       2.0    0.100
# 1187      DHT     500          10    Mean   (0.5, 0.5)       1.0    0.010
# 2953      DHT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 1173      DHT     500          10    Mean   (0.5, 0.5)       1.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 504        0.5       3        2       2           1       (1, 16, 16, 4)
# ...

# %%
dhtmean_kfold27.shape[0]
# Out:
# 3167

# %%
dhtmax_kfold27 = read_grid_search("results_v3/tsinghua_27_DHT_4_Max_kfold_1")
dhtmax_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2811      DHT     500          10     Max   (0.2, 0.2)       0.0    0.001
# 20        DHT     500          10     Max   (0.2, 0.2)       1.0    0.010
# 1326      DHT     500          10     Max   (0.5, 0.5)       1.0    0.010
# 1434      DHT     500          10     Max   (0.6, 0.2)       1.0    0.001
# 1158      DHT     500          10     Max  (0.3, 0.15)       1.0    0.001
# 1649      DHT     500          10     Max   (0.6, 0.2)       0.0    0.010
# 821       DHT     500          10     Max   (0.5, 0.5)       0.0    0.010
# 1074      DHT     500          10     Max   (0.2, 0.2)       2.0    0.100
# 3032      DHT     500          10     Max   (0.5, 0.5)       0.0    0.010
# 1408      DHT     500          10     Max   (0.3, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2811       0.5       3        2       1           5        (1, 8, 16, 4)
# ...

# %%
dhtmax_kfold27.shape[0]
# Out:
# 3152

# %% [markdown]
# #### Comparing the pooling types

# %%
# Sujeito 1
# DFT
a1 = dft_kfold.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a2 = dftmean_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a3 = dftmax_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
a4 = dht_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a5 = dhtmean_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a6 = dhtmax_kfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s1 = pd.concat((a1,a2,a3,a4,a5,a6))
results_s1
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 5116      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 412       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.100
# 2274      DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 5365      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 2852      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 684       DHT     500          10     Max  (0.3, 0.15)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 5116       0.5       3        2       1           1        (1, 8, 16, 4)
# 412        0.5       2        1       1           1       (1, 16, 16, 4)
# 2274       0.5       3        2       1           4        (1, 8, 16, 4)
# 5365       0.5       3        2       1           1        (1, 8, 16, 4)
# 2852       0.5       3        2       1           1         (1, 8, 8, 4)
# ...

# %%
print(results_s1.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 5116,DFT,500,10,Sum,"(0.6, 0.2)",0.0,0.001,0.5,3,2,1,1,"(1, 8, 16, 4)",opt7,0.01,0.8200001,20.96,54220
# 412,DFT,500,10,Mean,"(0.6, 0.2)",0.0,0.1,0.5,2,1,1,1,"(1, 16, 16, 4)",opt5,0.01,0.82,28.88,68356
# 2274,DFT,500,10,Max,"(0.5, 0.5)",0.0,0.1,0.5,3,2,1,4,"(1, 8, 16, 4)",opt4,0.0002,0.92,20.85,13612
# 5365,DHT,500,10,Sum,"(0.3, 0.5)",0.0,0.01,0.5,3,2,1,1,"(1, 8, 16, 4)",opt7,0.01,0.8400001,21.58,54220
# 2852,DHT,500,10,Mean,"(0.3, 0.5)",0.0,0.001,0.5,3,2,1,1,"(1, 8, 8, 4)",opt5,0.004,0.82,21.03,54116
# 684,DHT,500,10,Max,"(0.3, 0.15)",0.0,0.01,0.5,3,2,1,5,"(1, 16, 16, 4)",opt5,0.004,0.9200001,22.11,20756

# %%
# Sujeito 4
b1 = dft_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
b2 = dftmean_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
b3 = dftmax_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
b4 = dht_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
b5 = dhtmean_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
b6 = dhtmax_kfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s4 = pd.concat((b1,b2,b3,b4,b5,b6))
results_s4
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6527      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2121      DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 1379      DFT     500          10     Max   (0.5, 0.5)       0.0    0.100
# 2282      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 1589      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2934      DHT     500          10     Max  (0.3, 0.15)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6527       0.5       2        1       3           1       (1, 16, 16, 4)
# 2121       0.5       2        1       1           1         (1, 4, 8, 4)
# 1379       0.5       2        1       1           2       (1, 16, 16, 4)
# 2282       0.5       2        1       1           4         (1, 8, 8, 4)
# 1589       0.5       2        1       1           4         (1, 4, 8, 4)
# ...

# %%
print(results_s4.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 6527,DFT,500,10,Sum,"(0.3, 0.15)",0.0,0.001,0.5,2,1,3,1,"(1, 16, 16, 4)",opt8,0.01,0.88000005,27.85,201092
# 2121,DFT,500,10,Mean,"(0.3, 0.5)",0.0,0.1,0.5,2,1,1,1,"(1, 4, 8, 4)",opt5,0.01,0.84,27.85,20080
# 1379,DFT,500,10,Max,"(0.5, 0.5)",0.0,0.1,0.5,2,1,1,2,"(1, 16, 16, 4)",opt8,0.004,0.94,27.46,34356
# 2282,DHT,500,10,Sum,"(0.5, 0.5)",0.0,0.01,0.5,2,1,1,4,"(1, 8, 8, 4)",opt4,0.01,0.8400001,27.34,9044
# 1589,DHT,500,10,Mean,"(0.3, 0.15)",0.0,0.1,0.5,2,1,1,4,"(1, 4, 8, 4)",opt5,0.004,0.82,27.64,5040
# 2934,DHT,500,10,Max,"(0.3, 0.15)",0.0,0.001,0.5,3,2,1,5,"(1, 4, 8, 4)",opt4,0.004,0.90000004,20.66,6080

# %%
# Sujeito 13
c1 = dft_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
c2 = dftmean_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
c3 = dftmax_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
c4 = dht_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
c5 = dhtmean_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
c6 = dhtmax_kfold13.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s13 = pd.concat((c1,c2,c3,c4,c5,c6))
results_s13
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6626      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.001
# 3070      DFT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 1381      DFT     500          10     Max   (0.6, 0.2)       0.0    0.010
# 4992      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 656       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 1014      DHT     500          10     Max   (0.3, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6626       0.5       3        2       1           5       (1, 16, 16, 4)
# 3070       0.5       3        2       3           5        (1, 8, 16, 4)
# 1381       0.5       2        1       1           4         (1, 8, 8, 4)
# 4992       0.5       2        1       1           5       (1, 16, 16, 4)
# 656        0.5       3        2       2           1       (1, 16, 16, 4)
# ...

# %%
print(results_s13.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 6626,DFT,500,10,Sum,"(0.3, 0.5)",2.0,0.001,0.5,3,2,1,5,"(1, 16, 16, 4)",opt8,0.004,0.8600001,20.14,20756
# 3070,DFT,500,10,Mean,"(0.3, 0.15)",0.0,0.01,0.5,3,2,3,5,"(1, 8, 16, 4)",opt8,0.01,0.82,20.48,30604
# 1381,DFT,500,10,Max,"(0.6, 0.2)",0.0,0.01,0.5,2,1,1,4,"(1, 8, 8, 4)",opt5,0.01,0.92,27.81,9044
# 4992,DHT,500,10,Sum,"(0.5, 0.5)",0.0,0.1,0.5,2,1,1,5,"(1, 16, 16, 4)",opt8,0.01,0.8600001,27.71,13956
# 656,DHT,500,10,Mean,"(0.3, 0.15)",0.0,0.1,0.5,3,2,2,1,"(1, 16, 16, 4)",opt8,0.01,0.9200001,20.42,203540
# 1014,DHT,500,10,Max,"(0.3, 0.5)",0.0,0.01,0.5,2,1,1,1,"(1, 8, 16, 4)",opt8,0.01,0.94000006,26.22,36220

# %%
# Sujeito 27
d1 = dft_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
d2 = dftmean_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
d3 = dftmax_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
d4 = dht_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
d5 = dhtmean_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
d6 = dhtmax_kfold27.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s27 = pd.concat((d1,d2,d3,d4,d5,d6))
results_s27
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 450       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 919       DFT     500          10    Mean   (0.2, 0.2)       0.0    0.010
# 2411      DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 315       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 504       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 2811      DHT     500          10     Max   (0.2, 0.2)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 450        0.5       3        2       3           1       (1, 16, 16, 4)
# 919        0.5       3        2       1           1       (1, 16, 16, 4)
# 2411       0.5       3        2       1           3        (1, 8, 16, 4)
# 315        0.5       2        1       1           1       (1, 16, 16, 4)
# 504        0.5       3        2       2           1       (1, 16, 16, 4)
# ...

# %%
print(results_s27.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 450,DFT,500,10,Sum,"(0.2, 0.2)",0.0,0.1,0.5,3,2,3,1,"(1, 16, 16, 4)",opt8,0.01,0.96000004,20.47,303636
# 919,DFT,500,10,Mean,"(0.2, 0.2)",0.0,0.01,0.5,3,2,1,1,"(1, 16, 16, 4)",opt8,0.01,0.94,20.29,102356
# 2411,DFT,500,10,Max,"(0.2, 0.2)",1.0,0.1,0.5,3,2,1,3,"(1, 8, 16, 4)",opt8,0.001,0.98,19.97,18220
# 315,DHT,500,10,Sum,"(0.2, 0.2)",0.0,0.1,0.5,2,1,1,1,"(1, 16, 16, 4)",opt8,0.01,0.94,26.79,68356
# 504,DHT,500,10,Mean,"(0.3, 0.15)",0.0,0.1,0.5,3,2,2,1,"(1, 16, 16, 4)",opt8,0.01,1.0,20.6,203540
# 2811,DHT,500,10,Max,"(0.2, 0.2)",0.0,0.001,0.5,3,2,1,5,"(1, 8, 16, 4)",opt8,0.01,1.0,20.58,11020

# %% [markdown]
# ##### Evaluating all the subjects on the test set (retraining with train and val sets together) - not using yet

# %% [markdown]
# ###### DHT

# %%
dht_final = read_grid_search("results/final_35_DHT_top1_4")
dht_final.sort_values("Test_Accuracy", ascending=False)
# Out:
#     Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 14       31      DHT       0.5       3        2       1           1
# 27       13      DHT       0.5       3        2       1           1
# 6        22      DHT       0.5       3        2       1           1
# 24       32      DHT       0.5       3        2       1           1
# 32       26      DHT       0.5       3        2       1           1
# 16        8      DHT       0.5       3        2       1           1
# 2         4      DHT       0.5       3        2       1           1
# 3        35      DHT       0.5       3        2       1           1
# 4        20      DHT       0.5       3        2       1           1
# 22        1      DHT       0.5       3        2       1           1
# 10        5      DHT       0.5       3        2       1           1
# 8        16      DHT       0.5       3        2       1           1
# 18       14      DHT       0.5       3        2       1           1
# ...

# %%
dht_final.loc[:,"Test_Accuracy"].mean()
# Out:
# 0.7023809782857142

# %%
print(dht_final.sort_values("Test_Accuracy", ascending=False).to_latex())
# Out:
# \begin{tabular}{lrlrrrrrllrr}
# \toprule
# {} &  Subject & Function &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Test\_Accuracy \\
# \midrule
# 14 &       31 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 27 &       13 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 6  &       22 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 24 &       32 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 32 &       26 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# ...

# %% [markdown]
# ### Check results - Visual MNIST of the Brain

# %% [markdown]
# ##### Binary MNIST

# %%
# here we classify digit and non-digit
dft_mnist = read_grid_search("results/mnist_1_DFT_2_kfold_1")
dft_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 86       DFT     500          10   (0.2, 0.2)       1.0    0.001       0.0
# 235      DFT     500          10  (0.3, 0.15)       1.0    0.001       0.0
# 51       DFT     500          10   (0.3, 0.5)       1.0    0.010       0.0
# 1        DFT     500          10   (0.3, 0.5)       0.0    0.010       0.0
# 105      DFT     500          10  (0.3, 0.15)       2.0    0.001       0.0
# 135      DFT     500          10   (0.5, 0.5)       1.0    0.010       0.0
# 82       DFT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 72       DFT     500          10   (0.5, 0.5)       2.0    0.001       0.0
# 239      DFT     500          10   (0.3, 0.5)       1.0    0.100       0.0
# 80       DFT     500          10   (0.6, 0.2)       0.0    0.100       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
# here we classify digit and non-digit
dht_mnist = read_grid_search("results/mnist_1_DHT_2_kfold_1")
dht_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size     Dropout  FreqMean  FreqStd  Time_Off  \
# 53       DHT     500          10  (0.6, 0.2)       1.0    0.010       0.0
# 217      DHT     500          10  (0.3, 0.5)       1.0    0.001       0.0
# 157      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 108      DHT     500          10  (0.2, 0.2)       1.0    0.001       0.0
# 15       DHT     500          10  (0.3, 0.5)       1.0    0.100       0.0
# 72       DHT     500          10  (0.2, 0.2)       1.0    0.100       0.0
# 60       DHT     500          10  (0.3, 0.5)       0.0    0.010       0.0
# 129      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 187      DHT     500          10  (0.3, 0.5)       2.0    0.001       0.0
# 23       DHT     500          10  (0.2, 0.2)       2.0    0.010       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# 53        2        0       3           2         (1, 4, 8, 2)      opt8
# ...

# %% [markdown]
# ### Check results - BCI Competition Dataset IV 2a

# %% [markdown]
# #### K-Fold DFT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
bcic2akfold1 = read_grid_search("results_v3/bcic2a_1_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2541      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 418       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 2076      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1444      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2649      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 464       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 81        DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 1434      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 956       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 2475      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2541       0.0       5        0       3           1       (1, 16, 32, 4)
# ...

# %%
bcic2akfold1.shape[0]
# Out:
# 2741

# %%
print(bcic2akfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 2541 &      DFT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.010 &       0.0 &       5 &        0 &       3 &           1 &       (1, 16, 32, 4) &      opt5 &          0.004 &       0.745833 &  114.18 &  701194 \\
# 418  &      DFT &     500 &          10 &     Sum &   (0.3, 0.5) &       0.0 &    0.001 &       0.5 &       5 &        0 &       3 &           2 &        (1, 8, 16, 4) &      opt4 &          0.004 &       0.725000 &  116.18 &  183964 \\
# ...

# %%
bcic2akfold1mean = read_grid_search("results_v3/bcic2a_1_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold1mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1        DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 63       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 16       DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 54       DFT     500          10    Mean   (0.2, 0.2)       0.0    0.010
# 67       DFT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 64       DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 38       DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 8        DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 104      DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 19       DFT     500          10    Mean   (0.5, 0.5)       1.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1         0.0       5        0       2           2       (1, 16, 16, 4)
# ...

# %%
bcic2akfold1max = read_grid_search("results_v3/bcic2a_1_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold1max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 85       DFT     500          10     Max  (0.5, 0.5)       0.0    0.001
# 101      DFT     500          10     Max  (0.2, 0.2)       2.0    0.100
# 40       DFT     500          10     Max  (0.6, 0.2)       1.0    0.010
# 89       DFT     500          10     Max  (0.5, 0.5)       0.0    0.001
# 21       DFT     500          10     Max  (0.6, 0.2)       1.0    0.100
# 60       DFT     500          10     Max  (0.6, 0.2)       0.0    0.100
# 95       DFT     500          10     Max  (0.3, 0.5)       1.0    0.001
# 77       DFT     500          10     Max  (0.2, 0.2)       2.0    0.010
# 15       DFT     500          10     Max  (0.3, 0.5)       0.0    0.010
# 66       DFT     500          10     Max  (0.2, 0.2)       2.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 85        0.0       5        0       2           1       (1, 16, 16, 4)
# ...

# %%
bcic2akfold1max.shape
# Out:
# (125, 18)

# %% [markdown]
# ##### Subject 2

# %%
bcic2akfold2 = read_grid_search("results_v3/bcic2a_2_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold2.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 628       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1864      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 901       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 731       DFT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 1206      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 823       DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 745       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 443       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 1193      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 884       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 628        0.0       5        0       2           3       (1, 16, 32, 4)
# ...

# %%
bcic2akfold2.shape[0]
# Out:
# 2741

# %%
print(bcic2akfold2.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 628 &      DFT &     500 &          10 &     Sum &  (0.3, 0.5) &       0.0 &    0.010 &       0.0 &       5 &        0 &       2 &           3 &       (1, 16, 32, 4) &      opt5 &          0.004 &       0.579167 &  114.15 &  156276 \\
# 731 &      DFT &     500 &          10 &     Sum &  (0.2, 0.2) &       2.0 &    0.001 &       0.0 &       5 &        0 &       2 &           4 &       (1, 16, 32, 4) &      opt8 &          0.001 &       0.575000 &  110.33 &  117380 \\
# ...

# %%
bcic2akfold2mean = read_grid_search("results_v3/bcic2a_2_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold2mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 10      DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 16      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 12      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 36      DFT     500          10    Mean   (0.6, 0.2)       2.0    0.001
# 80      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 87      DFT     500          10    Mean   (0.3, 0.5)       1.0    0.100
# 92      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 91      DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 98      DFT     500          10    Mean   (0.5, 0.5)       0.0    0.001
# 11      DFT     500          10    Mean   (0.5, 0.5)       1.0    0.010
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 10       0.5       5        0       3           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold2max = read_grid_search("results_v3/bcic2a_2_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold2max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 86       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 91       DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
# 70       DFT     500          10     Max  (0.3, 0.15)       1.0    0.001
# 59       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 51       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 9        DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 61       DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 106      DFT     500          10     Max   (0.2, 0.2)       0.0    0.100
# 46       DFT     500          10     Max   (0.2, 0.2)       2.0    0.100
# 83       DFT     500          10     Max   (0.6, 0.2)       1.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 86        0.0       5        0       3           4       (1, 16, 32, 4)
# ...

# %% [markdown]
# ##### Subject 3

# %%
bcic2akfold3 = read_grid_search("results_v3/bcic2a_3_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold3.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 906       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 1408      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 2047      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2151      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1885      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2592      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.010
# 642       DFT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 141       DFT     500          10     Sum   (0.3, 0.5)       1.0    0.001
# 1667      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.100
# 1114      DFT     500          10     Sum   (0.5, 0.5)       2.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 906        0.5       5        0       3           4       (1, 16, 16, 4)
# ...

# %%
bcic2akfold3.shape[0]
# Out:
# 2740

# %%
print(bcic2akfold3.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 906  &      DFT &     500 &          10 &     Sum &  (0.5, 0.5) &       0.0 &    0.001 &       0.5 &       5 &        0 &       3 &           4 &       (1, 16, 16, 4) &      opt7 &          0.001 &       0.804167 &  114.88 &  170900 \\
# 1408 &      DFT &     500 &          10 &     Sum &  (0.5, 0.5) &       0.0 &    0.010 &       0.0 &       5 &        0 &       2 &           4 &       (1, 16, 16, 4) &      opt4 &          0.001 &       0.800000 &  116.98 &  117044 \\
# ...

# %%
bcic2akfold3max = read_grid_search("results_v3/bcic2a_3_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold3max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 54       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 85       DFT     500          10     Max   (0.5, 0.5)       0.0    0.001
# 116      DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 36       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 123      DFT     500          10     Max   (0.6, 0.2)       0.0    0.100
# 67       DFT     500          10     Max   (0.2, 0.2)       0.0    0.100
# 90       DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
# 87       DFT     500          10     Max   (0.2, 0.2)       2.0    0.100
# 24       DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 19       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 54        0.0       5        0       2           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold3mean = read_grid_search("results_v3/bcic2a_3_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold3mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 116      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 62       DFT     500          10    Mean   (0.6, 0.2)       2.0    0.001
# 80       DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 13       DFT     500          10    Mean   (0.6, 0.2)       2.0    0.100
# 83       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 50       DFT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 43       DFT     500          10    Mean   (0.3, 0.5)       2.0    0.100
# 19       DFT     500          10    Mean   (0.2, 0.2)       2.0    0.100
# 91       DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 61       DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 116       0.0       5        0       3           4       (1, 16, 16, 4)
# ...

# %% [markdown]
# ##### Subject 4

# %%
bcic2akfold4 = read_grid_search("results_v3/bcic2a_4_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 387       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 863       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 2298      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 1843      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 738       DFT     500          10     Sum   (0.2, 0.2)       1.0    0.001
# 1203      DFT     500          10     Sum   (0.6, 0.2)       1.0    0.001
# 1969      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 66        DFT     500          10     Sum   (0.3, 0.5)       2.0    0.100
# 1491      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 480       DFT     500          10     Sum   (0.2, 0.2)       2.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 387        0.5       5        0       3           5       (1, 16, 16, 4)
# ...

# %%
bcic2akfold4.shape[0]
# Out:
# 2740

# %%
print(bcic2akfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 387  &      DFT &     500 &          10 &     Sum &  (0.3, 0.5) &       0.0 &    0.001 &       0.5 &       5 &        0 &       3 &           5 &       (1, 16, 16, 4) &      opt5 &         0.0010 &       0.595833 &  115.86 &  135370 \\
# 863  &      DFT &     500 &          10 &     Sum &  (0.5, 0.5) &       0.0 &    0.100 &       0.5 &       5 &        0 &       3 &           5 &       (1, 16, 32, 4) &      opt4 &         0.0010 &       0.575000 &  117.55 &  135706 \\
# ...

# %%
bcic2akfold4mean = read_grid_search("results_v3/bcic2a_4_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold4mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 37       DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 45       DFT     500          10    Mean   (0.3, 0.5)       2.0    0.100
# 117      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 24       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 65       DFT     500          10    Mean   (0.3, 0.5)       2.0    0.010
# 61       DFT     500          10    Mean   (0.5, 0.5)       2.0    0.100
# 7        DFT     500          10    Mean   (0.6, 0.2)       2.0    0.001
# 10       DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 111      DFT     500          10    Mean   (0.6, 0.2)       2.0    0.100
# 116      DFT     500          10    Mean   (0.2, 0.2)       2.0    0.100
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 37        0.5       5        0       3           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold4max = read_grid_search("results_v3/bcic2a_4_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold4max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 83       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 82       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 36       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 113      DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 93       DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
# 32       DFT     500          10     Max   (0.6, 0.2)       1.0    0.010
# 96       DFT     500          10     Max   (0.5, 0.5)       2.0    0.010
# 97       DFT     500          10     Max   (0.2, 0.2)       0.0    0.100
# 105      DFT     500          10     Max   (0.2, 0.2)       2.0    0.100
# 99       DFT     500          10     Max   (0.3, 0.5)       2.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 83        0.0       5        0       2           4       (1, 16, 32, 4)
# ...

# %% [markdown]
# ##### Subject 5

# %%
bcic2akfold5 = read_grid_search("results_v3/bcic2a_5_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold5.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1252      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 1859      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 708       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 763       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2531      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2157      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 2190      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 400       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1273      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 54        DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1252       0.0       5        0       2           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold5.shape[0]
# Out:
# 2740

# %%
print(bcic2akfold5.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 1252 &      DFT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.010 &       0.0 &       5 &        0 &       2 &           4 &       (1, 16, 32, 4) &      opt7 &         0.0040 &       0.600000 &  115.49 &  117380 \\
# 708  &      DFT &     500 &          10 &     Sum &   (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       5 &        0 &       3 &           1 &       (1, 16, 16, 4) &      opt7 &         0.0040 &       0.595833 &  113.66 &  700858 \\
# ...

# %%
bcic2akfold5mean = read_grid_search("results_v3/bcic2a_5_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold5mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 63       DFT     500          10    Mean   (0.6, 0.2)       2.0    0.001
# 111      DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 26       DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 4        DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 29       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 78       DFT     500          10    Mean   (0.3, 0.5)       2.0    0.100
# 68       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 54       DFT     500          10    Mean   (0.2, 0.2)       0.0    0.001
# 114      DFT     500          10    Mean   (0.3, 0.5)       0.0    0.100
# 96       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 63        0.0       5        0       2           5       (1, 16, 16, 4)
# ...

# %%
bcic2akfold5max = read_grid_search("results_v3/bcic2a_5_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold5max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 76       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 79       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 103      DFT     500          10     Max   (0.5, 0.5)       2.0    0.010
# 78       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 97       DFT     500          10     Max   (0.2, 0.2)       1.0    0.100
# 95       DFT     500          10     Max   (0.6, 0.2)       0.0    0.100
# 57       DFT     500          10     Max   (0.5, 0.5)       0.0    0.001
# 94       DFT     500          10     Max   (0.5, 0.5)       1.0    0.100
# 124      DFT     500          10     Max   (0.6, 0.2)       1.0    0.100
# 0        DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 76        0.0       5        0       3           4       (1, 16, 32, 4)
# ...

# %% [markdown]
# #####  Subject 6

# %%
bcic2akfold6 = read_grid_search("results_v3/bcic2a_6_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold6.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 463       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 614       DFT     500          10     Sum   (0.6, 0.2)       2.0    0.100
# 994       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 1700      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2553      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 2176      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2209      DFT     500          10     Sum   (0.6, 0.2)       1.0    0.001
# 235       DFT     500          10     Sum   (0.2, 0.2)       1.0    0.001
# 1736      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.010
# 1675      DFT     500          10     Sum   (0.6, 0.2)       2.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 463        0.5       5        0       2           5       (1, 16, 16, 4)
# ...

# %%
bcic2akfold6.shape[0]
# Out:
# 2740

# %%
print(bcic2akfold6.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 463  &      DFT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.010 &       0.5 &       5 &        0 &       2 &           5 &       (1, 16, 16, 4) &      opt3 &         0.0010 &       0.525000 &  116.17 &   93482 \\
# 614  &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       2.0 &    0.100 &       0.0 &       5 &        0 &       3 &           3 &       (1, 16, 32, 4) &      opt4 &         0.0001 &       0.516667 &  119.23 &  234068 \\
# ...

# %%
bcic2akfold6mean = read_grid_search("results_v3/bcic2a_6_DFT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold6mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 43       DFT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 33       DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 22       DFT     500          10    Mean   (0.5, 0.5)       1.0    0.100
# 102      DFT     500          10    Mean  (0.3, 0.15)       2.0    0.010
# 66       DFT     500          10    Mean   (0.6, 0.2)       2.0    0.001
# 76       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 108      DFT     500          10    Mean   (0.3, 0.5)       2.0    0.010
# 68       DFT     500          10    Mean   (0.6, 0.2)       0.0    0.010
# 81       DFT     500          10    Mean   (0.5, 0.5)       1.0    0.010
# 57       DFT     500          10    Mean   (0.3, 0.5)       2.0    0.100
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 43        0.5       5        0       3           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold6max = read_grid_search("results_v3/bcic2a_6_DFT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold6max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 88       DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 5        DFT     500          10     Max   (0.2, 0.2)       2.0    0.010
# 100      DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 3        DFT     500          10     Max   (0.5, 0.5)       2.0    0.010
# 76       DFT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 29       DFT     500          10     Max   (0.3, 0.5)       2.0    0.100
# 94       DFT     500          10     Max   (0.6, 0.2)       1.0    0.001
# 64       DFT     500          10     Max   (0.3, 0.5)       1.0    0.001
# 27       DFT     500          10     Max   (0.2, 0.2)       2.0    0.100
# 41       DFT     500          10     Max   (0.6, 0.2)       1.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 88        0.0       5        0       3           5       (1, 16, 32, 4)
# ...

# %% [markdown]
# #### K-Fold DHT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
bcic2adhtkfold1 = read_grid_search("results_v3/bcic2a_1_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold1.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1513      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2326      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1605      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 86        DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 349       DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 937       DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 684       DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1461      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2484      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.100
# 2714      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1513       0.5       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold1.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 1513 &      DHT &     500 &          10 &     Sum &  (0.6, 0.2) &       0.0 &    0.001 &       0.5 &       5 &        0 &       2 &           3 &       (1, 16, 16, 4) &      opt5 &          0.010 &       0.729167 &  118.26 &  155940 \\
# 2326 &      DHT &     500 &          10 &     Sum &  (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       5 &        0 &       3 &           3 &       (1, 16, 32, 4) &      opt3 &          0.004 &       0.720833 &  115.41 &  234068 \\
# ...

# %%
bcic2adhtkfold1mean = read_grid_search("results_v3/bcic2a_1_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold1mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 60      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 21      DHT     500          10    Mean   (0.2, 0.2)       0.0    0.001
# 27      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 60       0.0       5        0       1           3       (1, 16, 32, 4)
# 21       0.0       5        0       2           1       (1, 16, 32, 4)
# 27       0.5       5        0       3           5       (1, 16, 16, 4)
#
#    Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 60      opt4          0.004       0.687500  111.93   78484
# 21      opt3          0.004       0.683333  113.84  467818
# 27      opt4          0.004       0.679167  112.56  135370

# %%
bcic2adhtkfold1mean.shape[0]
# Out:
# 108

# %%
bcic2adhtkfold1max = read_grid_search("results_v3/bcic2a_1_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold1max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 46      DHT     500          10     Max   (0.2, 0.2)       0.0    0.010
# 5       DHT     500          10     Max   (0.6, 0.2)       0.0    0.010
# 22      DHT     500          10     Max  (0.3, 0.15)       0.0    0.001
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 46       0.0       5        0       3           3       (1, 16, 16, 4)
# 5        0.0       5        0       3           2         (1, 4, 8, 4)
# 22       0.0       5        0       3           4        (1, 8, 16, 4)
#
#    Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 46      opt5         0.0040       0.704167  114.87  233732
# 5       opt5         0.0001       0.691667  114.72  102160
# 22      opt5         0.0010       0.675000  114.40   90508

# %%
bcic2adhtkfold1max.shape[0]
# Out:
# 126

# %% [markdown]
# ##### Subject 2

# %%
bcic2adhtkfold2 = read_grid_search("results_v3/bcic2a_2_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold2.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1325      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 203       DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 319       DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 2049      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 1208      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 1755      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 2430      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1578      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 1899      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1750      DHT     500          10     Sum   (0.6, 0.2)       1.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1325       0.0       5        0       2           3       (1, 16, 32, 4)
# ...

# %%
bcic2adhtkfold2.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold2.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 1325 &      DHT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &     0.10 &       0.0 &       5 &        0 &       2 &           3 &       (1, 16, 32, 4) &      opt3 &          0.001 &       0.595833 &  118.12 &  156276 \\
# 203  &      DHT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &     0.01 &       0.0 &       5 &        0 &       3 &           2 &       (1, 16, 32, 4) &      opt7 &          0.004 &       0.583333 &  117.11 &  347764 \\
# ...

# %%
bcic2adhtkfold2mean = read_grid_search("results_v3/bcic2a_2_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold2mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 4       DHT     500          10    Mean  (0.3, 0.15)       2.0    0.100
# 98      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.100
# 44      DHT     500          10    Mean   (0.3, 0.5)       1.0    0.001
# 11      DHT     500          10    Mean   (0.2, 0.2)       0.0    0.010
# 55      DHT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 32      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 60      DHT     500          10    Mean   (0.3, 0.5)       1.0    0.001
# 7       DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
# 33      DHT     500          10    Mean  (0.3, 0.15)       1.0    0.100
# 64      DHT     500          10    Mean   (0.2, 0.2)       2.0    0.010
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 4        0.5       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold2max = read_grid_search("results_v3/bcic2a_2_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold2max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 48       DHT     500          10     Max   (0.3, 0.5)       0.0    0.100
# 102      DHT     500          10     Max   (0.2, 0.2)       0.0    0.010
# 11       DHT     500          10     Max   (0.6, 0.2)       1.0    0.010
# 107      DHT     500          10     Max   (0.3, 0.5)       2.0    0.010
# 20       DHT     500          10     Max   (0.3, 0.5)       2.0    0.100
# 94       DHT     500          10     Max   (0.2, 0.2)       1.0    0.010
# 97       DHT     500          10     Max   (0.3, 0.5)       1.0    0.010
# 85       DHT     500          10     Max   (0.3, 0.5)       2.0    0.001
# 116      DHT     500          10     Max  (0.3, 0.15)       0.0    0.100
# 27       DHT     500          10     Max   (0.2, 0.2)       1.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 48        0.5       5        0       3           4       (1, 16, 16, 4)
# ...

# %% [markdown]
# ##### Subject 3

# %%
bcic2adhtkfold3 = read_grid_search("results_v3/bcic2a_3_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold3.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 70        DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 704       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 1709      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.010
# 1724      DHT     500          10     Sum   (0.6, 0.2)       1.0    0.100
# 55        DHT     500          10     Sum   (0.6, 0.2)       2.0    0.100
# 2734      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.010
# 2510      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2264      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 2358      DHT     500          10     Sum   (0.5, 0.5)       1.0    0.001
# 1061      DHT     500          10     Sum   (0.3, 0.5)       2.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 70         0.0       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold3.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold3.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 1724 &      DHT &     500 &          10 &     Sum &  (0.6, 0.2) &       1.0 &     0.10 &       0.0 &       5 &        0 &       2 &           5 &       (1, 16, 16, 4) &      opt8 &          0.001 &       0.754167 &  111.37 &   93482 \\
# 70   &      DHT &     500 &          10 &     Sum &  (0.2, 0.2) &       0.0 &     0.01 &       0.0 &       5 &        0 &       2 &           3 &       (1, 16, 16, 4) &      opt3 &          0.001 &       0.754167 &  114.27 &  155940 \\
# ...

# %%
bcic2adhtkfold3mean = read_grid_search("results_v3/bcic2a_3_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold3mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 63      DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
# 59      DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 10      DHT     500          10    Mean  (0.3, 0.15)       2.0    0.100
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 63       0.5       5        0       2           5       (1, 16, 16, 4)
# 59       0.5       5        0       3           5       (1, 16, 16, 4)
# 10       0.5       5        0       2           3       (1, 16, 16, 4)
#
#    Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 63      opt8         0.0010       0.750000  110.36   93482
# 59      opt4         0.0040       0.741667  114.23  135370
# 10      opt7         0.0001       0.741667  113.99  155940

# %%
bcic2adhtkfold3max = read_grid_search("results_v3/bcic2a_3_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold3max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 109      DHT     500          10     Max   (0.2, 0.2)       0.0    0.010
# 117      DHT     500          10     Max  (0.3, 0.15)       0.0    0.001
# 35       DHT     500          10     Max   (0.3, 0.5)       2.0    0.100
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 109       0.0       5        0       3           3       (1, 16, 16, 4)
# 117       0.0       5        0       3           4        (1, 8, 16, 4)
# 35        0.5       5        0       2           4       (1, 16, 16, 4)
#
#     Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 109      opt5         0.0040       0.775000  115.19  233732
# 117      opt5         0.0010       0.712500  115.39   90508
# 35       opt5         0.0001       0.708333  116.65  117044

# %% [markdown]
# ##### Subject 4

# %%
bcic2adhtkfold4 = read_grid_search("results_v3/bcic2a_4_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2279      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2342      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1122      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 738       DHT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 2218      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 856       DHT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 2732      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.001
# 657       DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1006      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 922       DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2279       0.0       5        0       2           5       (1, 16, 32, 4)
# ...

# %%
bcic2adhtkfold4.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 2279 &      DHT &     500 &          10 &     Sum &  (0.2, 0.2) &       0.0 &     0.01 &       0.0 &       5 &        0 &       2 &           5 &       (1, 16, 32, 4) &      opt7 &         0.0010 &       0.541667 &  118.33 &   93818 \\
# 2218 &      DHT &     500 &          10 &     Sum &  (0.6, 0.2) &       0.0 &     0.01 &       0.0 &       5 &        0 &       3 &           5 &       (1, 16, 32, 4) &      opt4 &         0.0001 &       0.529167 &  117.25 &  135706 \\
# ...

# %%
bcic2adhtkfold4mean = read_grid_search("results_v3/bcic2a_4_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold4mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#    Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 82      DHT     500          10    Mean  (0.3, 0.15)       2.0    0.100
# 61      DHT     500          10    Mean   (0.5, 0.5)       2.0    0.001
# 72      DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 82       0.5       5        0       2           3       (1, 16, 16, 4)
# 61       0.5       5        0       3           2       (1, 16, 32, 4)
# 72       0.5       5        0       2           5       (1, 16, 16, 4)
#
#    Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 82      opt7         0.0001       0.520833  115.14  155940
# 61      opt7         0.0010       0.491667  113.41  347764
# 72      opt8         0.0010       0.470833  111.44   93482

# %%
bcic2adhtkfold4max = read_grid_search("results_v3/bcic2a_4_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold4max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(3)
# Out:
#    Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 44      DHT     500          10     Max  (0.3, 0.5)       1.0     0.01
# 13      DHT     500          10     Max  (0.6, 0.2)       1.0     0.01
# 20      DHT     500          10     Max  (0.2, 0.2)       0.0     0.01
#
#     Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 44       0.0       5        0       3           5       (1, 16, 16, 4)
# 13       0.5       5        0       2           5       (1, 16, 32, 4)
# 20       0.0       5        0       3           3       (1, 16, 16, 4)
#
#    Optimizer  Learning_Rate  Mean_Accuracy    Time  Params
# 44      opt3          0.001       0.475000  110.97  135370
# 13      opt8          0.001       0.462500  109.43   93818
# 20      opt5          0.004       0.458333  117.38  233732

# %% [markdown]
# ##### Subject 5

# %%
bcic2adhtkfold5 = read_grid_search("results_v3/bcic2a_5_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold5.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 65        DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2168      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2485      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 1004      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 478       DHT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 842       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 2691      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2567      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1338      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2510      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 65         0.5       5        0       3           4       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold5.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold5.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 65   &      DHT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.010 &       0.5 &       5 &        0 &       3 &           4 &       (1, 16, 16, 4) &      opt7 &         0.0040 &       0.629167 &  115.19 &  170900 \\
# 2168 &      DHT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.001 &       0.0 &       5 &        0 &       3 &           4 &       (1, 16, 16, 4) &      opt5 &         0.0040 &       0.629167 &  119.19 &  170900 \\
# ...

# %%
bcic2adhtkfold5mean = read_grid_search("results_v3/bcic2a_5_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold5mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 47       DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 8        DHT     500          10    Mean   (0.5, 0.5)       1.0    0.100
# 99       DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
# 93       DHT     500          10    Mean  (0.3, 0.15)       2.0    0.100
# 76       DHT     500          10    Mean   (0.2, 0.2)       0.0    0.001
# 105      DHT     500          10    Mean  (0.3, 0.15)       1.0    0.100
# 69       DHT     500          10    Mean   (0.2, 0.2)       2.0    0.100
# 46       DHT     500          10    Mean  (0.3, 0.15)       0.0    0.010
# 52       DHT     500          10    Mean   (0.2, 0.2)       1.0    0.100
# 62       DHT     500          10    Mean   (0.3, 0.5)       1.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 47        0.5       5        0       3           5       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold5max = read_grid_search("results_v3/bcic2a_5_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold5max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 12       DHT     500          10     Max   (0.6, 0.2)       1.0    0.001
# 10       DHT     500          10     Max   (0.5, 0.5)       2.0    0.100
# 121      DHT     500          10     Max   (0.3, 0.5)       0.0    0.100
# 120      DHT     500          10     Max   (0.3, 0.5)       1.0    0.010
# 84       DHT     500          10     Max   (0.3, 0.5)       0.0    0.010
# 72       DHT     500          10     Max   (0.3, 0.5)       2.0    0.010
# 71       DHT     500          10     Max   (0.3, 0.5)       0.0    0.001
# 92       DHT     500          10     Max   (0.2, 0.2)       0.0    0.010
# 66       DHT     500          10     Max   (0.3, 0.5)       2.0    0.100
# 67       DHT     500          10     Max  (0.3, 0.15)       1.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 12        0.0       5        0       2           3       (1, 16, 32, 4)
# ...

# %% [markdown]
# ##### Subject 6

# %%
bcic2adhtkfold6 = read_grid_search("results_v3/bcic2a_6_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold6.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1559      DHT     500          10     Sum   (0.6, 0.2)       2.0    0.010
# 710       DHT     500          10     Sum   (0.6, 0.2)       2.0    0.100
# 1545      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 1547      DHT     500          10     Sum   (0.6, 0.2)       2.0    0.001
# 1765      DHT     500          10     Sum   (0.6, 0.2)       1.0    0.100
# 2150      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 2009      DHT     500          10     Sum   (0.3, 0.5)       2.0    0.100
# 280       DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2489      DHT     500          10     Sum   (0.2, 0.2)       1.0    0.100
# 2299      DHT     500          10     Sum   (0.6, 0.2)       1.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1559       0.0       5        0       3           3       (1, 16, 32, 4)
# ...

# %%
bcic2adhtkfold6.shape[0]
# Out:
# 2794

# %%
print(bcic2adhtkfold6.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &    Time &  Params \\
# \midrule
# 1559 &      DHT &     500 &          10 &     Sum &   (0.6, 0.2) &       2.0 &    0.010 &       0.0 &       5 &        0 &       3 &           3 &       (1, 16, 32, 4) &      opt7 &         0.0001 &       0.520833 &  115.61 &  234068 \\
# 710  &      DHT &     500 &          10 &     Sum &   (0.6, 0.2) &       2.0 &    0.100 &       0.5 &       5 &        0 &       3 &           3 &       (1, 16, 32, 4) &      opt8 &         0.0010 &       0.508333 &  114.11 &  234068 \\
# ...

# %%
bcic2adhtkfold6mean = read_grid_search("results_v3/bcic2a_6_DHT_4_Mean_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold6mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 62       DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
# 47       DHT     500          10    Mean  (0.3, 0.15)       1.0    0.100
# 102      DHT     500          10    Mean   (0.2, 0.2)       2.0    0.010
# 20       DHT     500          10    Mean   (0.3, 0.5)       0.0    0.001
# 74       DHT     500          10    Mean  (0.3, 0.15)       2.0    0.100
# 107      DHT     500          10    Mean   (0.2, 0.2)       1.0    0.010
# 1        DHT     500          10    Mean   (0.2, 0.2)       0.0    0.001
# 92       DHT     500          10    Mean   (0.2, 0.2)       0.0    0.100
# 49       DHT     500          10    Mean  (0.3, 0.15)       1.0    0.100
# 85       DHT     500          10    Mean   (0.3, 0.5)       1.0    0.001
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 62        0.0       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2adhtkfold6max = read_grid_search("results_v3/bcic2a_6_DHT_4_Max_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2adhtkfold6max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 91       DHT     500          10     Max  (0.3, 0.5)       2.0    0.001
# 100      DHT     500          10     Max  (0.3, 0.5)       2.0    0.010
# 32       DHT     500          10     Max  (0.6, 0.2)       1.0    0.010
# 118      DHT     500          10     Max  (0.2, 0.2)       1.0    0.010
# 96       DHT     500          10     Max  (0.6, 0.2)       2.0    0.100
# 113      DHT     500          10     Max  (0.2, 0.2)       1.0    0.010
# 26       DHT     500          10     Max  (0.2, 0.2)       2.0    0.100
# 15       DHT     500          10     Max  (0.3, 0.5)       1.0    0.010
# 40       DHT     500          10     Max  (0.6, 0.2)       0.0    0.100
# 45       DHT     500          10     Max  (0.3, 0.5)       0.0    0.100
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 91        0.0       5        0       3           5       (1, 16, 32, 4)
# ...

# %% [markdown]
# ##### Final training with best config - not using yet

# %%
#### Classification using DHT and no validation set (training and evaluating on the test set)
bcic2a = read_grid_search("results/final_bcic2a_1_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[108], line 2
#       1 #### Classification using DHT and no validation set (training and evaluating on the test set)
# ----> 2 bcic2a = read_grid_search("results/final_bcic2a_1_DHT_top10_4")
#       3 bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
#
# File ~/Git_Projects/PhD/experiments/main_functions/utils.py:96, in read_grid_search(path_to_results)
#      93 #create empty dataframe
#      94 data = pd.DataFrame()
# ---> 96 for archive in os.listdir(folder_path):
#      97     file = os.path.join(folder_path,archive)
#      98     single_data = pd.read_csv(file, index_col=0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/natalia/Git_Projects/PhD/experiments/results/final_bcic2a_1_DHT_top10_4'

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        8      DHT       0.0       5        0       3           5
# 6        3      DHT       0.0       5        0       3           5
# 7        9      DHT       0.0       5        0       3           5
# 2        1      DHT       0.0       5        0       3           5
# 8        4      DHT       0.0       5        0       3           5
# 3        2      DHT       0.0       5        0       3           5
# 5        7      DHT       0.0       5        0       3           5
# 1        6      DHT       0.0       5        0       3           5
# 4        5      DHT       0.0       5        0       3           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt3          0.001       0.704861
# 6             [64, 64]      opt3          0.001       0.697917
# 7             [64, 64]      opt3          0.001       0.604167
# ...

# %%
bcic2a = read_grid_search("results/final_bcic2a_1_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        1      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt8          0.001          0.625

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 5        8      DFT       0.0       5        0       2           5
# 1        9      DFT       0.0       5        0       2           5
# 3        3      DFT       0.0       5        0       2           5
# 4        1      DFT       0.0       5        0       2           5
# 7        4      DFT       0.0       5        0       2           5
# 6        2      DFT       0.0       5        0       2           5
# 8        7      DFT       0.0       5        0       2           5
# 0        6      DFT       0.0       5        0       2           5
# 2        5      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 5             [64, 64]      opt8          0.001       0.697917
# 1             [64, 64]      opt8          0.001       0.687500
# 3             [64, 64]      opt8          0.001       0.687500
# ...

# %% [markdown]
# #### Comparing the pooling types

# %%
# Sujeito 1
# DFT
a1 = bcic2akfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a2 = bcic2akfold1mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a3 = bcic2akfold1max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
a4 = bcic2adhtkfold1.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a5 = bcic2adhtkfold1mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a6 = bcic2adhtkfold1max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s1 = pd.concat((a1,a2,a3,a4,a5,a6))
print(results_s1.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 2541,DFT,500,10,Sum,"(0.5, 0.5)",0.0,0.01,0.0,5,0,3,1,"(1, 16, 32, 4)",opt5,0.004,0.74583334,114.18,701194
# 1,DFT,500,10,Mean,"(0.6, 0.2)",0.0,0.01,0.0,5,0,2,2,"(1, 16, 16, 4)",opt5,0.004,0.71666664,116.49,233732
# 85,DFT,500,10,Max,"(0.5, 0.5)",0.0,0.001,0.0,5,0,2,1,"(1, 16, 16, 4)",opt3,0.01,0.6958333,115.17,467482
# 1513,DHT,500,10,Sum,"(0.6, 0.2)",0.0,0.001,0.5,5,0,2,3,"(1, 16, 16, 4)",opt5,0.01,0.7291667,118.26,155940
# 60,DHT,500,10,Mean,"(0.3, 0.15)",0.0,0.01,0.0,5,0,1,3,"(1, 16, 32, 4)",opt4,0.004,0.6875,111.93,78484
# 46,DHT,500,10,Max,"(0.2, 0.2)",0.0,0.01,0.0,5,0,3,3,"(1, 16, 16, 4)",opt5,0.004,0.70416665,114.87,233732

# %%
# Sujeito 2
# DFT
a1 = bcic2akfold2.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a2 = bcic2akfold2mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a3 = bcic2akfold2max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
a4 = bcic2adhtkfold2.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a5 = bcic2adhtkfold2mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a6 = bcic2adhtkfold2max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s2 = pd.concat((a1,a2,a3,a4,a5,a6))
print(results_s2.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 628,DFT,500,10,Sum,"(0.3, 0.5)",0.0,0.01,0.0,5,0,2,3,"(1, 16, 32, 4)",opt5,0.004,0.57916665,114.15,156276
# 10,DFT,500,10,Mean,"(0.2, 0.2)",1.0,0.1,0.5,5,0,3,4,"(1, 16, 32, 4)",opt4,0.0001,0.5541667,114.98,171236
# 86,DFT,500,10,Max,"(0.2, 0.2)",2.0,0.01,0.0,5,0,3,4,"(1, 16, 32, 4)",opt7,0.0001,0.5375,115.71,171236
# 1325,DHT,500,10,Sum,"(0.5, 0.5)",0.0,0.1,0.0,5,0,2,3,"(1, 16, 32, 4)",opt3,0.001,0.5958333,118.12,156276
# 4,DHT,500,10,Mean,"(0.3, 0.15)",2.0,0.1,0.5,5,0,2,3,"(1, 16, 16, 4)",opt7,0.0001,0.54583335,113.15,155940
# 48,DHT,500,10,Max,"(0.3, 0.5)",0.0,0.1,0.5,5,0,3,4,"(1, 16, 16, 4)",opt5,0.0001,0.5083334,117.12,170900

# %%
# Sujeito 3
# DFT
a1 = bcic2akfold3.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a2 = bcic2akfold3mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a3 = bcic2akfold3max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
a4 = bcic2adhtkfold3.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a5 = bcic2adhtkfold3mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a6 = bcic2adhtkfold3max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s3 = pd.concat((a1,a2,a3,a4,a5,a6))
print(results_s3.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 906,DFT,500,10,Sum,"(0.5, 0.5)",0.0,0.001,0.5,5,0,3,4,"(1, 16, 16, 4)",opt7,0.001,0.80416673,114.88,170900
# 116,DFT,500,10,Mean,"(0.3, 0.15)",2.0,0.01,0.0,5,0,3,4,"(1, 16, 16, 4)",opt4,0.0001,0.7833334,112.33,170900
# 54,DFT,500,10,Max,"(0.3, 0.15)",0.0,0.001,0.0,5,0,2,4,"(1, 16, 32, 4)",opt4,0.001,0.74583334,112.57,117380
# 1724,DHT,500,10,Sum,"(0.6, 0.2)",1.0,0.1,0.0,5,0,2,5,"(1, 16, 16, 4)",opt8,0.001,0.7541667,111.37,93482
# 63,DHT,500,10,Mean,"(0.2, 0.2)",1.0,0.01,0.5,5,0,2,5,"(1, 16, 16, 4)",opt8,0.001,0.75,110.36,93482
# 109,DHT,500,10,Max,"(0.2, 0.2)",0.0,0.01,0.0,5,0,3,3,"(1, 16, 16, 4)",opt5,0.004,0.77500004,115.19,233732

# %%
# Sujeito 4
# DFT
a1 = bcic2akfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a2 = bcic2akfold4mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a3 = bcic2akfold4max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
# DHT
a4 = bcic2adhtkfold4.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a5 = bcic2adhtkfold4mean.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
a6 = bcic2adhtkfold4max.sort_values(["Mean_Accuracy", "Params"], ascending=[False, True]).head(1)
results_s4 = pd.concat((a1,a2,a3,a4,a5,a6))
print(results_s4.to_csv())
# Out:
# ,Function,Epochs,Batch_Size,Pooling,Dropout,FreqMean,FreqStd,Time_Off,Window,Overlap,Levels,Band_Width,Neuron_Configuration,Optimizer,Learning_Rate,Mean_Accuracy,Time,Params
# 387,DFT,500,10,Sum,"(0.3, 0.5)",0.0,0.001,0.5,5,0,3,5,"(1, 16, 16, 4)",opt5,0.001,0.5958333,115.86,135370
# 37,DFT,500,10,Mean,"(0.2, 0.2)",1.0,0.1,0.5,5,0,3,4,"(1, 16, 32, 4)",opt4,0.0001,0.525,112.22,171236
# 83,DFT,500,10,Max,"(0.3, 0.15)",0.0,0.001,0.0,5,0,2,4,"(1, 16, 32, 4)",opt4,0.001,0.54583335,115.19,117380
# 2279,DHT,500,10,Sum,"(0.2, 0.2)",0.0,0.01,0.0,5,0,2,5,"(1, 16, 32, 4)",opt7,0.001,0.5416667,118.33,93818
# 82,DHT,500,10,Mean,"(0.3, 0.15)",2.0,0.1,0.5,5,0,2,3,"(1, 16, 16, 4)",opt7,0.0001,0.5208334,115.14,155940
# 44,DHT,500,10,Max,"(0.3, 0.5)",1.0,0.01,0.0,5,0,3,5,"(1, 16, 16, 4)",opt3,0.001,0.475,110.97,135370

# %% [markdown]
# ### Check results - Motion Sense

# %% [markdown]
# #### DHT

# %%
motionsensedhtsum = read_grid_search("toys/MS_MultiSubject_DHT_6_Sum") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedhtsum.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 9516      DHT     500         256     Sum   (0.2, 0.2)       0.0    0.001
# 6977      DHT     500         256     Sum   (0.6, 0.2)       2.0    0.010
# 6193      DHT     500         256     Sum   (0.5, 0.5)       1.0    0.010
# 4090      DHT     500         256     Sum   (0.2, 0.2)       2.0    0.001
# 2237      DHT     500         256     Sum  (0.3, 0.15)       0.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 9516       0.0       3        0       2           1       (1, 32, 32, 6)
# 6977       0.0       3        0       1           2        (1, 8, 16, 6)
# 6193       0.0       3        0       1           2       (1, 16, 32, 6)
# 4090       0.0       3        0       1           2        (1, 8, 16, 6)
# 2237       0.0       3        0       1           2       (1, 32, 32, 6)
#
#      Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...

# %%
motionsensedhtsum.shape
# Out:
# (12560, 18)

# %%
motionsensedhtmean = read_grid_search("toys/MS_MultiSubject_DHT_6_Mean") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedhtmean.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#       Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 4139       DHT     500         256    Mean  (0.2, 0.2)       1.0    0.100
# 769        DHT     500         256    Mean  (0.5, 0.5)       0.0    0.010
# 10331      DHT     500         256    Mean  (0.3, 0.5)       1.0    0.010
# 11555      DHT     500         256    Mean  (0.2, 0.2)       1.0    0.001
# 8929       DHT     500         256    Mean  (0.5, 0.5)       0.0    0.100
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 4139        0.0       3        0       1           2        (1, 8, 16, 6)
# 769         0.0       3        0       2           1       (1, 32, 32, 6)
# 10331       0.0       3        0       1           2       (1, 16, 32, 6)
# 11555       0.0       3        0       1           1       (1, 32, 32, 6)
# 8929        0.0       3        0       1           2       (1, 32, 32, 6)
#
#       Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...

# %%
motionsensedhtmax = read_grid_search("toys/MS_MultiSubject_DHT_6_Max") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedhtmax.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#       Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 7775       DHT     500         256     Max   (0.3, 0.5)       1.0    0.010
# 8943       DHT     500         256     Max   (0.2, 0.2)       1.0    0.010
# 4135       DHT     500         256     Max  (0.3, 0.15)       1.0    0.100
# 12096      DHT     500         256     Max   (0.3, 0.5)       1.0    0.001
# 325        DHT     500         256     Max  (0.3, 0.15)       1.0    0.010
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 7775        0.0       3        0       1           1       (1, 32, 32, 6)
# 8943        0.0       3        0       1           1       (1, 32, 32, 6)
# 4135        0.0       3        0       1           1       (1, 32, 32, 6)
# 12096       0.0       3        0       1           1       (1, 32, 32, 6)
# 325         0.0       3        0       1           1       (1, 32, 32, 6)
#
#       Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...

# %% [markdown]
# #### DFT

# %%
motionsensedftsum = read_grid_search("toys/MS_MultiSubject_DFT_6_Sum") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedftsum.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#       Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 9990       DFT     500         256     Sum   (0.3, 0.5)       0.0    0.010
# 1278       DFT     500         256     Sum   (0.5, 0.5)       1.0    0.100
# 8793       DFT     500         256     Sum   (0.3, 0.5)       2.0    0.001
# 10202      DFT     500         256     Sum  (0.3, 0.15)       2.0    0.001
# 2877       DFT     500         256     Sum   (0.3, 0.5)       2.0    0.001
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 9990        0.0       3        0       1           1        (1, 8, 16, 6)
# 1278        0.0       3        0       2           1       (1, 32, 32, 6)
# 8793        0.0       3        0       2           2         (1, 4, 4, 6)
# 10202       0.0       3        0       2           2         (1, 4, 4, 6)
# 2877        0.0       3        0       1           2        (1, 8, 16, 6)
#
#       Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...

# %%
motionsensedhtsum.shape
# Out:
# (12560, 18)

# %%
motionsensedftmean = read_grid_search("toys/MS_MultiSubject_DFT_6_Mean") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedftmean.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 848       DFT     500         256    Mean  (0.3, 0.5)       0.0    0.001
# 8407      DFT     500         256    Mean  (0.6, 0.2)       2.0    0.100
# 3239      DFT     500         256    Mean  (0.2, 0.2)       2.0    0.001
# 8643      DFT     500         256    Mean  (0.3, 0.5)       2.0    0.001
# 9980      DFT     500         256    Mean  (0.3, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 848        0.0       3        0       1           2         (1, 4, 4, 6)
# 8407       0.0       3        0       1           2       (1, 32, 32, 6)
# 3239       0.0       3        0       1           2        (1, 8, 16, 6)
# 8643       0.0       3        0       1           2        (1, 8, 16, 6)
# 9980       0.0       3        0       1           1        (1, 8, 16, 6)
#
#      Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...

# %%
motionsensedftmax = read_grid_search("toys/MS_MultiSubject_DFT_6_Max") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
motionsensedftmax.sort_values(["Val_Accuracy", "Params"], ascending=[False, True]).head()
# Out:
#       Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 4876       DFT     500         256     Max   (0.6, 0.2)       0.0    0.100
# 1075       DFT     500         256     Max  (0.3, 0.15)       1.0    0.010
# 6812       DFT     500         256     Max   (0.2, 0.2)       1.0    0.010
# 10169      DFT     500          64     Max   (0.5, 0.5)       1.0    0.001
# 11675      DFT     500          64     Max   (0.6, 0.2)       1.0    0.001
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 4876        0.0       3        0       2           1       (1, 32, 32, 6)
# 1075        0.0       3        0       2           1       (1, 32, 32, 6)
# 6812        0.0       3        0       2           1       (1, 32, 32, 6)
# 10169       0.0       3        0       1           1       (1, 32, 32, 6)
# 11675       0.0       3        0       1           1       (1, 32, 32, 6)
#
#       Optimizer  Learning_Rate  Val_Accuracy   Time  Params
# ...
