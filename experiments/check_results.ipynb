# %% [markdown]
# #### Setup

# %%
from main_functions.utils import read_grid_search

# %% [markdown]
# #### Check top 10 results - DFT

# %%
b = read_grid_search("results/grid_search_1_DFT_top10_4")
b.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 903      DFT       0.5       3        1       1           1
# 202      DFT       0.5       3        2       1           1
# 286      DFT       0.5       3        1       1           1
# 409      DFT       0.5       3        1       2           2
# 840      DFT       0.5       3        2       1           1
# 159      DFT       0.5       3        1       1           2
# 459      DFT       0.5       3        2       2           2
# 831      DFT       0.5       3        1       2           1
# 778      DFT       0.5       3        2       3           1
# 457      DFT       0.5       3        1       3           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 903             (16, 16)      opt5         0.0001       0.825000
# 202             (16, 16)      opt5         0.0001       0.816667
# 286             (16, 16)      opt4         0.0001       0.800000
# ...

# %% [markdown]
# #### Check top 10 results - DHT

# %%
c = read_grid_search("results/grid_search_1_DHT_top10_4")
c.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 262      DHT       0.5       3        1       1           1
# 649      DHT       0.5       2        1       1           2
# 761      DHT       0.5       2        1       1           2
# 429      DHT       0.5       2        1       1           2
# 454      DHT       0.5       3        1       3           1
# 600      DHT       0.5       3        2       2           1
# 656      DHT       0.5       3        2       1           1
# 781      DHT       0.5       2        1       3           2
# 450      DHT       0.5       2        1       1           2
# 593      DHT       0.5       2        1       2           2
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 262             (16, 16)      opt4         0.0001       0.800000
# 649             (16, 16)      opt4         0.0001       0.750000
# 761             (16, 16)      opt5         0.0001       0.750000
# ...
