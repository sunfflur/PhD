# %% [markdown]
# #### Setup

# %%
from main_functions.utils import read_grid_search

# %% [markdown]
# #### Check top 10 results - DFT

# %%
b = read_grid_search("results/grid_search_1_DFT_top10_4")
b.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 760      DFT       0.5       3        1       1           1
# 166      DFT       0.5       3        2       1           1
# 708      DFT       0.5       3        2       1           1
# 375      DFT       0.5       3        2       2           2
# 701      DFT       0.5       3        1       2           1
# 656      DFT       0.5       3        2       3           1
# 134      DFT       0.5       3        1       1           2
# 237      DFT       0.5       3        1       1           1
# 796      DFT       0.5       2        1       1           2
# 373      DFT       0.5       3        1       3           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 760             (16, 16)      opt5         0.0001       0.825000
# 166             (16, 16)      opt5         0.0001       0.816667
# 708             (16, 16)      opt5         0.0001       0.800000
# 375             (16, 16)      opt3         0.0010       0.800000
# 701             (16, 16)      opt5         0.0001       0.800000
# 656             (16, 16)      opt5         0.0010       0.800000
# 134             (16, 16)      opt4         0.0080       0.800000
# 237             (16, 16)      opt4         0.0001       0.800000
# 796             (16, 16)      opt5         0.0001       0.775000
# 373             (16, 16)      opt5         0.0001       0.775000

# %% [markdown]
# #### Check top 10 results - DHT

# %%
c = read_grid_search("results/grid_search_1_DHT_top10_4")
c.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 226      DHT       0.5       3        1       1           1
# 653      DHT       0.5       2        1       1           2
# 561      DHT       0.5       2        1       1           2
# 393      DHT       0.5       3        1       3           1
# 370      DHT       0.5       2        1       1           2
# 524      DHT       0.5       3        2       2           1
# 670      DHT       0.5       2        1       3           2
# 389      DHT       0.5       2        1       1           2
# 519      DHT       0.5       2        1       2           2
# 182      DHT       0.5       3        1       1           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 226             (16, 16)      opt4         0.0001       0.800000
# 653             (16, 16)      opt5         0.0001       0.750000
# 561             (16, 16)      opt4         0.0001       0.750000
# 393             (16, 16)      opt5         0.0001       0.725000
# 370             (16, 16)      opt4         0.0001       0.725000
# 524             (16, 16)      opt4         0.0001       0.716667
# 670             (16, 16)      opt5         0.0001       0.712500
# 389             (16, 16)      opt4         0.0001       0.687500
# 519             (16, 16)      opt3         0.0010       0.675000
# 182             (16, 16)      opt5         0.0001       0.675000
