# %% [markdown]
# ### Setup

# %%
from main_functions.utils import read_grid_search

# %% [markdown]
# ### Check results - Tsinghua Dataset

# %% [markdown]
# #### k-fold DFT (1 subject) - correct

# %% [markdown]
# ##### Subject 1

# %%
dft_kfold = read_grid_search("results_v2/tsinghua_1_DFT_4_Sum_kfold_1")
dft_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 358      DFT     500          10     Sum   (0.5, 0.5)       1.0    0.010
# 408      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 150      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.010
# 591      DFT     500          10     Sum  (0.3, 0.15)       1.0    0.100
# 289      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 547      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 432      DFT     500          10     Sum   (0.2, 0.2)       1.0    0.001
# 259      DFT     500          10     Sum   (0.6, 0.2)       1.0    0.010
# 122      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.100
# 376      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 358       0.5       3        2       1           2        (1, 8, 16, 4)
# ...

# %%
dft_kfold.shape[0]
# Out:
# 645

# %% [markdown]
# ##### Subject 11

# %%
dft11_kfold = read_grid_search("results/tsinghua_11_DFT_4_kfold_1")
dft11_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#       Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 18160      DFT     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 16171      DFT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 20490      DFT     500          10   (0.5, 0.5)       0.0    0.001       0.5
# 10643      DFT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 15242      DFT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 11709      DFT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 9620       DFT     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 611        DFT     500          10   (0.2, 0.2)       0.0    0.001       0.5
# 12641      DFT     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 2630       DFT     500          10   (0.5, 0.5)       0.0    0.010       0.5
#
#        Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
dft11_kfold.shape[0]
# Out:
# 21400

# %%
print(dft11_kfold.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex(caption='Results of k-fold cross validation over trials for subject 11.'))
# Out:
# \begin{table}
# \centering
# \caption{Results of k-fold cross validation over trials for subject 11.}
# \begin{tabular}{llrrlrrrrrrrllrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy \\
# \midrule
# 18160 &      DFT &     500 &          10 &   (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       3 &        2 &       2 &           1 &        (1, 8, 16, 4) &      opt8 &          0.004 &           0.80 \\
# 16171 &      DFT &     500 &          10 &   (0.6, 0.2) &       0.0 &    0.010 &       0.5 &       3 &        2 &       2 &           1 &        (1, 8, 16, 4) &      opt8 &          0.004 &           0.80 \\
# ...

# %%
halfdft_kfold = read_grid_search("results/tsinghua_11_halfDFT_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
halfdft_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#       Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 6686   halfDFT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 8762   halfDFT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 8525   halfDFT     500          10   (0.2, 0.2)       0.0    0.010       0.5
# 11780  halfDFT     500          10   (0.5, 0.5)       0.0    0.001       0.5
# 6094   halfDFT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 4429   halfDFT     500          10  (0.3, 0.15)       0.0    0.100       0.5
# 1049   halfDFT     500          10  (0.3, 0.15)       0.0    0.001       0.5
# 8408   halfDFT     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 2797   halfDFT     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 5926   halfDFT     500          10   (0.5, 0.5)       0.0    0.100       0.5
#
#        Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
halfdft_kfold.shape[0]
# Out:
# 12312

# %% [markdown]
# #### k-fold DHT (1 subject) - correct

# %% [markdown]
# ##### Subject 1

# %%
# taking abs(DHT(original signal))
dht_kfold = read_grid_search("results_v2/tsinghua_1_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 111      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 470      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 28       DHT     500          10     Sum   (0.6, 0.2)       2.0    0.010
# 472      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 66       DHT     500          10     Sum   (0.2, 0.2)       1.0    0.001
# 278      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 260      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.100
# 147      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 130      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.010
# 309      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 111       0.5       3        2       1           4       (1, 16, 16, 4)
# ...

# %%
dht_kfold.shape[0]
# Out:
# 62

# %%
# taking abs(DHT(flipped signal))
dhtflip_kfold = read_grid_search("results/tsinghua_1_dataDHTflip_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
dhtflip_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 # taking abs(DHT(flipped signal))
# ----> 2 dhtflip_kfold = read_grid_search("results/tsinghua_1_dataDHTflip_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
#       3 dhtflip_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
#
# File ~/Git_Projects/PhD/experiments/main_functions/utils.py:98, in read_grid_search(path_to_results)
#      96 for archive in os.listdir(folder_path):
#      97     file = os.path.join(folder_path,archive)
# ---> 98     single_data = pd.read_csv(file, index_col=0)
#      99     data = pd.concat([data,single_data],axis=0)
#     101 return data.reset_index(drop=True)
#
# File ~/miniforge-pypy3/envs/PhD_test/lib/python3.12/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %%
dhtflip_kfold.shape[0]
# Out:
# 16403

# %%
# 'halfDHT' = without flipping and arcsinh
# taking half(abs(DHT(original signal)))
halfdht_kfold = read_grid_search("results/tsinghua_1_halfDHT_4_kfold_1") 
halfdht_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 2744  halfDHT     500          10   (0.3, 0.5)       0.0    0.001       0.5
# 529   halfDHT     500          10   (0.2, 0.2)       0.0    0.010       0.5
# 2946  halfDHT     500          10   (0.2, 0.2)       1.0    0.100       0.5
# 701   halfDHT     500          10   (0.5, 0.5)       0.0    0.100       0.5
# 3394  halfDHT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 1342  halfDHT     500          10  (0.3, 0.15)       0.0    0.100       0.5
# 1331  halfDHT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 781   halfDHT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 3231  halfDHT     500          10  (0.3, 0.15)       0.0    0.001       0.5
# 3292  halfDHT     500          10   (0.3, 0.5)       1.0    0.010       0.5
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
halfdht_kfold.shape[0]
# Out:
# 3467

# %%
# 'symDHTabs' = flipping and abs, not using arcsinh (is also considering haldf the transform)
# taking half(abs(DHT(flipped signal)))
symhalfdhtabs_kfold = read_grid_search("results/tsinghua_1_symDHTabs_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
symhalfdhtabs_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#        Function  Epochs  Batch_Size     Dropout  FreqMean  FreqStd  Time_Off  \
# 2243  symDHTabs     500          10  (0.6, 0.2)       0.0    0.001       0.5
# 2253  symDHTabs     500          10  (0.6, 0.2)       0.0    0.010       0.5
# 1494  symDHTabs     500          10  (0.6, 0.2)       0.0    0.100       0.5
# 2640  symDHTabs     500          10  (0.6, 0.2)       0.0    0.100       0.5
# 2813  symDHTabs     500          10  (0.3, 0.5)       0.0    0.100       0.5
# 2978  symDHTabs     500          10  (0.3, 0.5)       0.0    0.010       0.5
# 638   symDHTabs     500          10  (0.5, 0.5)       0.0    0.010       0.5
# 1076  symDHTabs     500          10  (0.3, 0.5)       0.0    0.010       0.5
# 2954  symDHTabs     500          10  (0.5, 0.5)       0.0    0.010       0.5
# 3420  symDHTabs     500          10  (0.5, 0.5)       0.0    0.001       0.5
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
symhalfdhtabs_kfold.shape[0]
# Out:
# 3439

# %% [markdown]
# ##### Subject 4

# %%
# taking abs(DHT(original signal))
dht_kfold4 = read_grid_search("results_v2/tsinghua_4_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 159      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 228      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 382      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.100
# 321      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 71       DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 37       DHT     500          10     Sum   (0.5, 0.5)       2.0    0.001
# 54       DHT     500          10     Sum   (0.5, 0.5)       2.0    0.010
# 269      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 429      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 352      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
#
#      Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 159       0.5       3        2       1           2       (1, 16, 16, 4)
# ...

# %%
# taking half(abs(DHT(original signal)))
halfdht_kfold4 = read_grid_search("results/tsinghua_4_halfDHT_4_kfold_1") 
halfdht_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 2313  halfDHT     500          10   (0.2, 0.2)       0.0    0.100       0.5
# 1040  halfDHT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 2037  halfDHT     500          10   (0.3, 0.5)       0.0    0.100       0.5
# 2845  halfDHT     500          10   (0.3, 0.5)       0.0    0.100       0.5
# 501   halfDHT     500          10   (0.5, 0.5)       0.0    0.001       0.5
# 1964  halfDHT     500          10   (0.2, 0.2)       0.0    0.100       0.5
# 624   halfDHT     500          10   (0.2, 0.2)       0.0    0.100       0.5
# 2466  halfDHT     500          10   (0.5, 0.5)       0.0    0.100       0.5
# 3175  halfDHT     500          10   (0.6, 0.2)       0.0    0.001       0.5
# 2290  halfDHT     500          10   (0.2, 0.2)       0.0    0.100       0.5
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
# taking half(abs(DHT(flipped signal)))
symhalfdhtabs_kfold4 = read_grid_search("results/tsinghua_4_symDHTabs_4_kfold_1") #grid_search_subject_DHT_top10_classes_kfold_true
symhalfdhtabs_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#        Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 1100  symDHTabs     500          10  (0.3, 0.15)       0.0    0.100       0.5
# 3225  symDHTabs     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 2943  symDHTabs     500          10   (0.6, 0.2)       0.0    0.001       0.5
# 1805  symDHTabs     500          10   (0.5, 0.5)       0.0    0.010       0.5
# 1728  symDHTabs     500          10   (0.5, 0.5)       0.0    0.100       0.5
# 2154  symDHTabs     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 793   symDHTabs     500          10   (0.3, 0.5)       0.0    0.100       0.5
# 3281  symDHTabs     500          10   (0.5, 0.5)       0.0    0.001       0.5
# 1623  symDHTabs     500          10   (0.3, 0.5)       0.0    0.010       0.5
# 1904  symDHTabs     500          10   (0.3, 0.5)       0.0    0.001       0.5
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %% [markdown]
# ##### Subject 11

# %%
dht11_kfold = read_grid_search("results/tsinghua_11_DHT_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht11_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#       Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 10675      DHT     500          10   (0.6, 0.2)       0.0    0.001       0.5
# 7015       DHT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 3763       DHT     500          10   (0.2, 0.2)       0.0    0.001       0.5
# 3773       DHT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 483        DHT     500          10   (0.5, 0.5)       0.0    0.001       0.5
# 17         DHT     500          10   (0.5, 0.5)       0.0    0.010       0.5
# 14336      DHT     500          10  (0.3, 0.15)       0.0    0.001       0.5
# 20505      DHT     500          10   (0.5, 0.5)       0.0    0.010       0.5
# 19981      DHT     500          10   (0.6, 0.2)       0.0    0.010       0.5
# 7488       DHT     500          10  (0.3, 0.15)       0.0    0.010       0.5
#
#        Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
dht11_kfold.shape[0]
# Out:
# 21491

# %%
print(dht11_kfold.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex(caption='Results of k-fold cross validation over trials for subject 11.'))
# Out:
# \begin{table}
# \centering
# \caption{Results of k-fold cross validation over trials for subject 11.}
# \begin{tabular}{llrrlrrrrrrrllrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy \\
# \midrule
# 10675 &      DHT &     500 &          10 &   (0.6, 0.2) &       0.0 &    0.001 &       0.5 &       3 &        2 &       3 &           1 &        (1, 8, 16, 4) &      opt8 &          0.010 &           0.74 \\
# 7015  &      DHT &     500 &          10 &  (0.3, 0.15) &       0.0 &    0.010 &       0.5 &       3 &        2 &       3 &           1 &        (1, 8, 16, 4) &      opt8 &          0.010 &           0.70 \\
# ...

# %%
halfdht_kfold = read_grid_search("results/tsinghua_11_halfDHT_4_kfold_1") #neither arcsinh or flip
halfdht_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#       Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 5650   halfDHT     500          10  (0.3, 0.15)       0.0    0.010       0.5
# 8663   halfDHT     500          10   (0.6, 0.2)       0.0    0.001       0.5
# 14732  halfDHT     500          10   (0.3, 0.5)       2.0    0.010       0.5
# 3025   halfDHT     500          10   (0.2, 0.2)       0.0    0.001       0.5
# 15902  halfDHT     500          10   (0.2, 0.2)       1.0    0.001       0.5
# 15872  halfDHT     500          10  (0.3, 0.15)       2.0    0.010       0.5
# 3876   halfDHT     500          10   (0.3, 0.5)       2.0    0.010       0.5
# 4954   halfDHT     500          10   (0.5, 0.5)       1.0    0.001       0.5
# 12058  halfDHT     500          10   (0.2, 0.2)       0.0    0.100       0.5
# 6536   halfDHT     500          10   (0.5, 0.5)       2.0    0.010       0.5
#
#        Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
halfdht_kfold.shape[0]
# Out:
# 17301

# %%
# here I'm starting to flip the input data
dhtflip_kfold = read_grid_search("results/tsinghua_11_dataDHTflip_4_kfold_1") #grid_search_1_DHT_top10_4_kfold
dhtflip_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#           Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  \
# 14847  dataDHTflip     500          10   (0.2, 0.2)       0.0    0.010
# 14426  dataDHTflip     500          10   (0.2, 0.2)       2.0    0.001
# 10022  dataDHTflip     500          10   (0.3, 0.5)       2.0    0.010
# 4855   dataDHTflip     500          10  (0.3, 0.15)       2.0    0.010
# 16222  dataDHTflip     500          10  (0.3, 0.15)       2.0    0.010
# 243    dataDHTflip     500          10   (0.6, 0.2)       0.0    0.010
# 8943   dataDHTflip     500          10   (0.6, 0.2)       0.0    0.100
# 10563  dataDHTflip     500          10   (0.3, 0.5)       2.0    0.010
# 1639   dataDHTflip     500          10   (0.6, 0.2)       1.0    0.100
# 10970  dataDHTflip     500          10   (0.5, 0.5)       0.0    0.010
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 14847       0.5       3        2       1           4        (1, 8, 16, 4)
# ...

# %%
dhtflip_kfold.shape[0]
# Out:
# 16382

# %%
symhalfdht_kfold = read_grid_search("results/tsinghua_11_symDHT_4_kfold_1") #using arcsinh and abs and flip
symhalfdht_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#       Function  Epochs  Batch_Size     Dropout  FreqMean  FreqStd  Time_Off  \
# 12985   symDHT     500          10  (0.2, 0.2)       2.0    0.100       0.5
# 16684   symDHT     500          10  (0.6, 0.2)       1.0    0.001       0.5
# 9810    symDHT     500          10  (0.6, 0.2)       1.0    0.001       0.5
# 10862   symDHT     500          10  (0.2, 0.2)       2.0    0.100       0.5
# 7599    symDHT     500          10  (0.5, 0.5)       1.0    0.001       0.5
# 12790   symDHT     500          10  (0.2, 0.2)       2.0    0.100       0.5
# 9073    symDHT     500          10  (0.5, 0.5)       2.0    0.100       0.5
# 551     symDHT     500          10  (0.3, 0.5)       2.0    0.001       0.5
# 6080    symDHT     500          10  (0.6, 0.2)       1.0    0.100       0.5
# 11549   symDHT     500          10  (0.6, 0.2)       1.0    0.001       0.5
#
#        Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
symhalfdht_kfold.shape[0]
# Out:
# 17072

# %%
symhalfdhtabs_kfold = read_grid_search("results/tsinghua_11_symDHTabs_4_kfold_1") #not using arcsinh, only abs and flip
symhalfdhtabs_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#         Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  \
# 4686   symDHTabs     500          10   (0.5, 0.5)       0.0    0.010
# 801    symDHTabs     500          10   (0.2, 0.2)       1.0    0.100
# 19388  symDHTabs     500          10  (0.3, 0.15)       0.0    0.100
# 2768   symDHTabs     500          10   (0.5, 0.5)       1.0    0.010
# 19134  symDHTabs     500          10  (0.3, 0.15)       2.0    0.001
# 18776  symDHTabs     500          10   (0.2, 0.2)       1.0    0.100
# 21891  symDHTabs     500          10   (0.6, 0.2)       1.0    0.001
# 11865  symDHTabs     500          10   (0.3, 0.5)       2.0    0.100
# 3949   symDHTabs     500          10   (0.5, 0.5)       2.0    0.100
# 2302   symDHTabs     500          10  (0.3, 0.15)       2.0    0.100
#
#        Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 4686        0.5       2        1       2           3         (1, 8, 8, 4)
# ...

# %%
symhalfdhtabs_kfold.shape[0]
# Out:
# 22926

# %% [markdown]
# ##### Evaluating all the subjects on the test set (retraining with train and val sets together) - redo

# %% [markdown]
# ###### DFT

# %%
dft_final = read_grid_search("results/final_35_DFT_top1_4")
dft_final.sort_values("Test_Accuracy", ascending=False)
# Out:
#     Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 3        32      DFT       0.5       3        2       1           1
# 22       26      DFT       0.5       3        2       1           1
# 5        22      DFT       0.5       3        2       1           1
# 21       31      DFT       0.5       3        2       1           1
# 12        4      DFT       0.5       3        2       1           1
# 14        8      DFT       0.5       3        2       1           1
# 17       20      DFT       0.5       3        2       1           1
# 24        1      DFT       0.5       3        2       1           1
# 20       30      DFT       0.5       3        2       1           1
# 18       35      DFT       0.5       3        2       1           1
# 34       13      DFT       0.5       3        2       1           1
# 10       27      DFT       0.5       3        2       1           1
# 32        9      DFT       0.5       3        2       1           1
# ...

# %%
dft_final.loc[:,"Test_Accuracy"].mean()
# Out:
# 0.6357143097142857

# %%
print(dft_final.sort_values("Test_Accuracy", ascending=False).to_latex())
# Out:
# \begin{tabular}{lrlrrrrrllrr}
# \toprule
# {} &  Subject & Function &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Test\_Accuracy \\
# \midrule
# 3  &       32 &      DFT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &          0.004 &       1.000000 \\
# 22 &       26 &      DFT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &          0.004 &       1.000000 \\
# 5  &       22 &      DFT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &          0.004 &       1.000000 \\
# 21 &       31 &      DFT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &          0.004 &       1.000000 \\
# 12 &        4 &      DFT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &          0.004 &       0.916667 \\
# ...

# %% [markdown]
# ###### DHT

# %%
dht_final = read_grid_search("results/final_35_DHT_top1_4")
dht_final.sort_values("Test_Accuracy", ascending=False)
# Out:
#     Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 14       31      DHT       0.5       3        2       1           1
# 27       13      DHT       0.5       3        2       1           1
# 6        22      DHT       0.5       3        2       1           1
# 24       32      DHT       0.5       3        2       1           1
# 32       26      DHT       0.5       3        2       1           1
# 16        8      DHT       0.5       3        2       1           1
# 2         4      DHT       0.5       3        2       1           1
# 3        35      DHT       0.5       3        2       1           1
# 4        20      DHT       0.5       3        2       1           1
# 22        1      DHT       0.5       3        2       1           1
# 10        5      DHT       0.5       3        2       1           1
# 8        16      DHT       0.5       3        2       1           1
# 18       14      DHT       0.5       3        2       1           1
# ...

# %%
dht_final.loc[:,"Test_Accuracy"].mean()
# Out:
# 0.7023809782857142

# %%
print(dht_final.sort_values("Test_Accuracy", ascending=False).to_latex())
# Out:
# \begin{tabular}{lrlrrrrrllrr}
# \toprule
# {} &  Subject & Function &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Test\_Accuracy \\
# \midrule
# 14 &       31 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 27 &       13 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 6  &       22 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 24 &       32 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 32 &       26 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# ...

# %%
dft_kfold12 = read_grid_search("results/grid_search_1_DFT_top10_4_kfold12")
dft_kfold12.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 816       DFT       0.5       2        1       1           2
# 211       DFT       0.5       3        2       2           2
# 227       DFT       0.5       3        2       2           2
# 183       DFT       0.5       3        2       2           2
# 337       DFT       0.5       3        2       3           2
# 1080      DFT       0.5       3        2       1           1
# 974       DFT       0.5       3        2       2           2
# 864       DFT       0.5       3        2       1           1
# 840       DFT       0.5       3        2       2           1
# 833       DFT       0.5       3        2       1           2
#
#      Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 816                [4, 8]      opt8         0.0040           0.56
# 211                [4, 8]      opt5         0.0002           0.54
# 227                [4, 8]      opt4         0.0001           0.54
# ...

# %%
dht_kfold12 = read_grid_search("results/grid_search_1_DHT_top10_4_kfold12")
dht_kfold12.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 183       DHT       0.5       3        2       2           2
# 1297      DHT       0.5       3        2       1           2
# 227       DHT       0.5       3        2       2           2
# 106       DHT       0.5       3        2       2           2
# 162       DHT       0.5       3        2       2           2
# 1721      DHT       0.5       3        2       3           2
# 1589      DHT       0.5       3        2       1           2
# 596       DHT       0.5       3        2       3           2
# 1763      DHT       0.5       3        2       3           2
# 1711      DHT       0.5       3        2       2           2
#
#      Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 183                [4, 8]      opt7         0.0001           0.58
# 1297               [4, 8]      opt5         0.0010           0.56
# 227                [4, 8]      opt4         0.0001           0.56
# ...

# %%
dht_kfold11 = read_grid_search("results/grid_search_15_DHT_top10_4_kfold11")
dht_kfold11.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 347      DHT       0.5       3        2       1           1
# 185      DHT       0.5       3        2       1           1
# 357      DHT       0.5       3        2       2           1
# 117      DHT       0.5       3        2       2           1
# 59       DHT       0.5       3        2       1           1
# 379      DHT       0.5       3        2       2           1
# 272      DHT       0.5       3        2       3           1
# 80       DHT       0.5       3        2       1           1
# 88       DHT       0.5       3        2       2           1
# 103      DHT       0.5       3        2       1           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 347               [4, 8]      opt8         0.0002       0.561429
# 185               [4, 8]      opt8         0.0010       0.537333
# 357               [4, 8]      opt8         0.0010       0.534667
# ...

# %%
dht_kfold24 = read_grid_search("results/grid_search_15_DHT_top10_4_kfold24")
dht_kfold24.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 301      DHT       0.5       3        2       1           1
# 152      DHT       0.5       3        2       2           1
# 241      DHT       0.5       3        2       1           1
# 365      DHT       0.5       3        2       1           1
# 166      DHT       0.5       3        2       1           1
# 248      DHT       0.5       3        2       1           1
# 304      DHT       0.5       3        2       2           1
# 323      DHT       0.5       3        2       1           1
# 312      DHT       0.5       3        2       3           1
# 62       DHT       0.5       3        2       1           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 301               [4, 8]      opt8         0.0001           0.76
# 152               [4, 8]      opt8         0.0040           0.74
# 241               [4, 8]      opt8         0.0010           0.74
# ...

# %%
dht_kfold19 = read_grid_search("results/grid_search_15_DHT_top10_4_kfold19")
dht_kfold19.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 353      DHT       0.5       3        2       3           1
# 242      DHT       0.5       3        2       3           1
# 298      DHT       0.5       3        2       2           1
# 147      DHT       0.5       3        2       2           2
# 238      DHT       0.5       3        2       1           1
# 40       DHT       0.5       3        2       2           2
# 239      DHT       0.5       3        2       1           1
# 18       DHT       0.5       3        2       2           2
# 360      DHT       0.5       3        2       1           1
# 258      DHT       0.5       3        2       3           1
#
#     Neuron_Configuration Optimizer  Learning_Rate  Mean_Accuracy
# 353               [4, 8]      opt5         0.0010           0.54
# 242               [4, 8]      opt7         0.0002           0.54
# 298               [4, 8]      opt5         0.0040           0.52
# ...

# %% [markdown]
# ### Check results - Visual MNIST of the Brain

# %% [markdown]
# ##### Binary MNIST

# %%
# here we classify digit and non-digit
dft_mnist = read_grid_search("results/mnist_1_DFT_2_kfold_1")
dft_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 86       DFT     500          10   (0.2, 0.2)       1.0    0.001       0.0
# 235      DFT     500          10  (0.3, 0.15)       1.0    0.001       0.0
# 51       DFT     500          10   (0.3, 0.5)       1.0    0.010       0.0
# 1        DFT     500          10   (0.3, 0.5)       0.0    0.010       0.0
# 105      DFT     500          10  (0.3, 0.15)       2.0    0.001       0.0
# 135      DFT     500          10   (0.5, 0.5)       1.0    0.010       0.0
# 82       DFT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 72       DFT     500          10   (0.5, 0.5)       2.0    0.001       0.0
# 239      DFT     500          10   (0.3, 0.5)       1.0    0.100       0.0
# 80       DFT     500          10   (0.6, 0.2)       0.0    0.100       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
# here we classify digit and non-digit
dht_mnist = read_grid_search("results/mnist_1_DHT_2_kfold_1")
dht_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size     Dropout  FreqMean  FreqStd  Time_Off  \
# 53       DHT     500          10  (0.6, 0.2)       1.0    0.010       0.0
# 217      DHT     500          10  (0.3, 0.5)       1.0    0.001       0.0
# 157      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 108      DHT     500          10  (0.2, 0.2)       1.0    0.001       0.0
# 15       DHT     500          10  (0.3, 0.5)       1.0    0.100       0.0
# 72       DHT     500          10  (0.2, 0.2)       1.0    0.100       0.0
# 60       DHT     500          10  (0.3, 0.5)       0.0    0.010       0.0
# 129      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 187      DHT     500          10  (0.3, 0.5)       2.0    0.001       0.0
# 23       DHT     500          10  (0.2, 0.2)       2.0    0.010       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# 53        2        0       3           2         (1, 4, 8, 2)      opt8
# ...

# %% [markdown]
# ### Check results - BCI Competition Dataset IV 2a

# %% [markdown]
# #### K-Fold cross validation over trials with dropout, freqmean and freqstd variation - correct

# %% [markdown]
# ##### Subject 1

# %%
bcic2akfold = read_grid_search("results/bcic2a_1_DFT_4_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 6813      DFT     500          10  (0.3, 0.15)       0.0    0.010       0.0
# 1588      DFT     500          10   (0.3, 0.5)       0.0    0.010       0.0
# 4534      DFT     500          10   (0.3, 0.5)       0.0    0.100       0.0
# 3011      DFT     500          10   (0.2, 0.2)       0.0    0.010       0.0
# 4518      DFT     500          10   (0.5, 0.5)       0.0    0.010       0.0
# 7683      DFT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 7358      DFT     500          10   (0.3, 0.5)       0.0    0.010       0.0
# 4831      DFT     500          10   (0.5, 0.5)       0.0    0.010       0.0
# 4364      DFT     500          10   (0.2, 0.2)       0.0    0.100       0.0
# 5164      DFT     500          10   (0.5, 0.5)       0.0    0.010       0.0
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
bcic2akfold.shape[0]
# Out:
# 8947

# %%
print(bcic2akfold.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrlrrrrrrrllrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Training\_Time &  Mean\_Accuracy \\
# \midrule
# 6813 &      DFT &     500 &          10 &  (0.3, 0.15) &       0.0 &    0.010 &       0.0 &       5 &        0 &       3 &           2 &       (1, 16, 32, 4) &      opt5 &          0.001 &      20.016668 &       0.741667 \\
# 1588 &      DFT &     500 &          10 &   (0.3, 0.5) &       0.0 &    0.010 &       0.0 &       5 &        0 &       3 &           2 &       (1, 16, 32, 4) &      opt5 &          0.001 &      19.201668 &       0.741667 \\
# 4534 &      DFT &     500 &          10 &   (0.3, 0.5) &       0.0 &    0.100 &       0.0 &       5 &        0 &       3 &           4 &       (1, 16, 16, 4) &      opt3 &          0.004 &      19.806667 &       0.729167 \\
# ...

# %%
bcic2akfolddht = read_grid_search("results/bcic2a_1_DHT_4_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfolddht.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 2018      DHT     500          10  (0.3, 0.15)       0.0    0.001       0.0
# 1105      DHT     500          10   (0.6, 0.2)       1.0    0.010       0.0
# 5754      DHT     500          10   (0.6, 0.2)       0.0    0.100       0.0
# 3942      DHT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 1266      DHT     500          10  (0.3, 0.15)       2.0    0.100       0.0
# 6242      DHT     500          10   (0.6, 0.2)       2.0    0.001       0.0
# 719       DHT     500          10  (0.3, 0.15)       0.0    0.001       0.0
# 1910      DHT     500          10   (0.5, 0.5)       0.0    0.010       0.0
# 805       DHT     500          10   (0.2, 0.2)       0.0    0.100       0.0
# 3091      DHT     500          10   (0.5, 0.5)       1.0    0.010       0.0
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
bcic2akfolddht.shape[0]
# Out:
# 8975

# %%
print(bcic2akfolddht.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrlrrrrrrrllrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Training\_Time &  Mean\_Accuracy \\
# \midrule
# 2018 &      DHT &     500 &          10 &  (0.3, 0.15) &       0.0 &    0.001 &       0.0 &       5 &        0 &       2 &           5 &       (1, 32, 64, 4) &      opt3 &         0.0010 &      19.553335 &       0.687500 \\
# 1105 &      DHT &     500 &          10 &   (0.6, 0.2) &       1.0 &    0.010 &       0.0 &       5 &        0 &       2 &           5 &       (1, 32, 64, 4) &      opt5 &         0.0001 &      19.598333 &       0.687500 \\
# 5754 &      DHT &     500 &          10 &   (0.6, 0.2) &       0.0 &    0.100 &       0.0 &       5 &        0 &       2 &           5 &       (1, 16, 16, 4) &      opt5 &         0.0040 &      20.156668 &       0.683333 \\
# ...

# %% [markdown]
# ##### Subject 4

# %%
bcic2a4kfold = read_grid_search("results/bcic2a_4_DFT_4_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2a4kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 1722      DFT     500          10   (0.3, 0.5)       0.0    0.001       0.0
# 5109      DFT     500          10   (0.2, 0.2)       1.0    0.100       0.0
# 8389      DFT     500          10   (0.2, 0.2)       1.0    0.100       0.0
# 578       DFT     500          10   (0.3, 0.5)       0.0    0.100       0.0
# 9261      DFT     500          10   (0.3, 0.5)       1.0    0.001       0.0
# 8315      DFT     500          10   (0.6, 0.2)       0.0    0.001       0.0
# 4042      DFT     500          10   (0.5, 0.5)       2.0    0.100       0.0
# 3036      DFT     500          10  (0.3, 0.15)       0.0    0.100       0.0
# 205       DFT     500          10   (0.5, 0.5)       0.0    0.010       0.0
# 72        DFT     500          10   (0.5, 0.5)       2.0    0.001       0.0
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
bcic2a4kfold.shape[0]
# Out:
# 9362

# %%
bcic2a4kfolddht = read_grid_search("results/bcic2a_4_DHT_4_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2a4kfolddht.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 8461      DHT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 3341      DHT     500          10  (0.3, 0.15)       2.0    0.100       0.0
# 7623      DHT     500          10   (0.3, 0.5)       1.0    0.010       0.0
# 9224      DHT     500          10   (0.6, 0.2)       1.0    0.100       0.0
# 5439      DHT     500          10   (0.6, 0.2)       2.0    0.010       0.0
# 5445      DHT     500          10  (0.3, 0.15)       0.0    0.001       0.0
# 6234      DHT     500          10   (0.5, 0.5)       0.0    0.010       0.0
# 417       DHT     500          10  (0.3, 0.15)       0.0    0.010       0.0
# 2372      DHT     500          10   (0.2, 0.2)       0.0    0.100       0.0
# 8517      DHT     500          10   (0.5, 0.5)       0.0    0.010       0.0
#
#       Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
bcic2a4kfolddht.shape[0]
# Out:
# 9371

# %% [markdown]
# ##### Final training with best config - redo

# %%
#### Classification using DHT and no validation set (training and evaluating on the test set)
bcic2a = read_grid_search("results/final_bcic2a_1_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        1      DHT       0.0       5        0       3           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt3          0.001       0.600695

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        8      DHT       0.0       5        0       3           5
# 6        3      DHT       0.0       5        0       3           5
# 7        9      DHT       0.0       5        0       3           5
# 2        1      DHT       0.0       5        0       3           5
# 8        4      DHT       0.0       5        0       3           5
# 3        2      DHT       0.0       5        0       3           5
# 5        7      DHT       0.0       5        0       3           5
# 1        6      DHT       0.0       5        0       3           5
# 4        5      DHT       0.0       5        0       3           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt3          0.001       0.704861
# 6             [64, 64]      opt3          0.001       0.697917
# 7             [64, 64]      opt3          0.001       0.604167
# ...

# %%
bcic2a = read_grid_search("results/final_bcic2a_1_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        1      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt8          0.001          0.625

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 5        8      DFT       0.0       5        0       2           5
# 1        9      DFT       0.0       5        0       2           5
# 3        3      DFT       0.0       5        0       2           5
# 4        1      DFT       0.0       5        0       2           5
# 7        4      DFT       0.0       5        0       2           5
# 6        2      DFT       0.0       5        0       2           5
# 8        7      DFT       0.0       5        0       2           5
# 0        6      DFT       0.0       5        0       2           5
# 2        5      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 5             [64, 64]      opt8          0.001       0.697917
# 1             [64, 64]      opt8          0.001       0.687500
# 3             [64, 64]      opt8          0.001       0.687500
# ...
