# %% [markdown]
# ### Setup

# %%
from main_functions.utils import read_grid_search

# %% [markdown]
# ### Check results - Tsinghua Dataset

# %% [markdown]
# #### k-fold DFT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
dft_kfold = read_grid_search("results_v3/tsinghua_1_DFT_4_Sum_kfold_1")
dft_kfold.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 5116      DFT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 6668      DFT     500          10     Sum  (0.2, 0.2)       1.0    0.100
# 2578      DFT     500          10     Sum  (0.5, 0.5)       0.0    0.100
# 2142      DFT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 4         DFT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 462       DFT     500          10     Sum  (0.5, 0.5)       2.0    0.010
# 1180      DFT     500          10     Sum  (0.5, 0.5)       0.0    0.100
# 3344      DFT     500          10     Sum  (0.6, 0.2)       1.0    0.001
# 1732      DFT     500          10     Sum  (0.5, 0.5)       1.0    0.001
# 7420      DFT     500          10     Sum  (0.3, 0.5)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 5116       0.5       3        2       1           1        (1, 8, 16, 4)
# ...

# %%
dft_kfold.shape[0]
# Out:
# 7876

# %%
print(dft_kfold.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 6668 &      DFT &     500 &          10 &     Sum &   (0.2, 0.2) &       1.0 &    0.100 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt8 &          0.004 &           0.82 &  21.06 &   54220 \\
# 5116 &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.001 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt7 &          0.010 &           0.82 &  20.96 &   54220 \\
# ...

# %% [markdown]
# ##### Subject 4

# %%
# taking abs(DHT(original signal))
dft_kfold4 = read_grid_search("results_v3/tsinghua_4_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6525      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1552      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 7431      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 3108      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 4825      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 4751      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 6638      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 994       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 1525      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 5987      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6525       0.5       2        1       3           1       (1, 16, 16, 4)
# ...

# %%
dft_kfold4.shape[0]
# Out:
# 7876

# %%
print(dft_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 6525 &      DFT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.001 &       0.5 &       2 &        1 &       3 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.88 &  27.85 &  201092 \\
# 1552 &      DFT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.100 &       0.5 &       3 &        2 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.86 &  20.92 &  102356 \\
# ...

# %% [markdown]
# ##### Subject 13

# %%
# taking abs(DHT(original signal))
dft_kfold13 = read_grid_search("results_v3/tsinghua_13_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold13.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 6624      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.001
# 4062      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 6820      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 6543      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.010
# 3856      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 3526      DFT     500          10     Sum   (0.2, 0.2)       2.0    0.010
# 439       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2712      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 6202      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 4991      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 6624       0.5       3        2       1           5       (1, 16, 16, 4)
# ...

# %%
dft_kfold13.shape[0]
# Out:
# 7876

# %%
print(dft_kfold13.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 6624 &      DFT &     500 &          10 &     Sum &   (0.3, 0.5) &       2.0 &    0.001 &       0.5 &       3 &        2 &       1 &           5 &       (1, 16, 16, 4) &      opt8 &         0.0040 &           0.86 &  20.14 &   20756 \\
# 4062 &      DFT &     500 &          10 &     Sum &   (0.6, 0.2) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &         0.0100 &           0.86 &  26.94 &   68356 \\
# ...

# %% [markdown]
# ##### Subject 27

# %%
# taking abs(DHT(original signal))
dft_kfold27 = read_grid_search("results_v3/tsinghua_27_DFT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dft_kfold27.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 450       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 4910      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 3924      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 5329      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 339       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 594       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 7397      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 1391      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 4868      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 2160      DFT     500          10     Sum   (0.2, 0.2)       1.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 450        0.5       3        2       3           1       (1, 16, 16, 4)
# ...

# %%
dft_kfold27.shape[0]
# Out:
# 7876

# %%
print(dft_kfold27.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 450  &      DFT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.100 &       0.5 &       3 &        2 &       3 &           1 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.96 &  20.47 &  303636 \\
# 4910 &      DFT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.010 &       0.5 &       3 &        2 &       3 &           1 &        (1, 8, 16, 4) &      opt8 &          0.010 &           0.90 &  20.82 &  160780 \\
# ...

# %% [markdown]
# #### k-fold DHT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
# taking abs(DHT(original signal))
dht_kfold1 = read_grid_search("results_v3/tsinghua_1_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold1.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 5365      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.010
# 7578      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 7134      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 2606      DHT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 6953      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.010
# 4809      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.010
# 581       DHT     500          10     Sum  (0.2, 0.2)       0.0    0.010
# 2077      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 3027      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.001
# 1083      DHT     500          10     Sum  (0.3, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 5365       0.5       3        2       1           1        (1, 8, 16, 4)
# ...

# %%
dht_kfold1.shape[0]
# Out:
# 7629

# %%
print(dht_kfold1.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &     Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 5365 &      DHT &     500 &          10 &     Sum &  (0.3, 0.5) &       0.0 &    0.010 &       0.5 &       3 &        2 &       1 &           1 &        (1, 8, 16, 4) &      opt7 &         0.0100 &           0.84 &  21.58 &   54220 \\
# 7578 &      DHT &     500 &          10 &     Sum &  (0.5, 0.5) &       0.0 &    0.001 &       0.5 &       3 &        2 &       1 &           1 &       (1, 16, 16, 4) &      opt3 &         0.0100 &           0.84 &  21.86 &  102356 \\
# ...

# %% [markdown]
# ##### Subject 4

# %%
# taking abs(DHT(original signal))
dht_kfold4 = read_grid_search("results_v3/tsinghua_4_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2282      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 3581      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 4411      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 6372      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 4394      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 3765      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 2289      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 1452      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 4402      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.100
# 4907      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.001
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2282       0.5       2        1       1           4         (1, 8, 8, 4)
# ...

# %%
dht_kfold4.shape[0]
# Out:
# 7629

# %%
print(dht_kfold4.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 2282 &      DHT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           4 &         (1, 8, 8, 4) &      opt4 &          0.010 &           0.84 &  27.34 &    9044 \\
# 3581 &      DHT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.100 &       0.5 &       2 &        1 &       3 &           2 &         (1, 4, 8, 4) &      opt8 &          0.010 &           0.84 &  27.34 &   28960 \\
# ...

# %% [markdown]
# ##### Subject 13

# %%
# taking abs(DHT(original signal))
dht_kfold13 = read_grid_search("results_v3/tsinghua_13_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold13.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1914      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 4992      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 4727      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 3724      DHT     500          10     Sum  (0.3, 0.15)       1.0    0.100
# 1513      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 6322      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 818       DHT     500          10     Sum   (0.6, 0.2)       2.0    0.100
# 1775      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 3588      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 2656      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1914       0.5       2        1       1           2       (1, 16, 16, 4)
# ...

# %%
dht_kfold13.shape[0]
# Out:
# 7628

# %%
print(dht_kfold13.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 1914 &      DHT &     500 &          10 &     Sum &  (0.3, 0.15) &       0.0 &    0.010 &       0.5 &       2 &        1 &       1 &           2 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.86 &  28.08 &   34356 \\
# 4992 &      DHT &     500 &          10 &     Sum &   (0.5, 0.5) &       0.0 &    0.100 &       0.5 &       2 &        1 &       1 &           5 &       (1, 16, 16, 4) &      opt8 &          0.010 &           0.86 &  27.71 &   13956 \\
# ...

# %% [markdown]
# ##### Subject 27

# %%
# taking abs(DHT(original signal))
dht_kfold27 = read_grid_search("results_v3/tsinghua_27_DHT_4_Sum_kfold_1") #grid_search_1_DHT_top10_4_kfold
dht_kfold27.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 315       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 822       DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 775       DHT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 2647      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 4953      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 1053      DHT     500          10     Sum   (0.5, 0.5)       1.0    0.001
# 3705      DHT     500          10     Sum   (0.3, 0.5)       2.0    0.001
# 4922      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 2660      DHT     500          10     Sum   (0.5, 0.5)       2.0    0.010
# 5590      DHT     500          10     Sum  (0.3, 0.15)       2.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 315        0.5       2        1       1           1       (1, 16, 16, 4)
# ...

# %%
dht_kfold27.shape[0]
# Out:
# 7628

# %%
print(dht_kfold27.sort_values("Mean_Accuracy",ascending=False).head(10).to_latex())
# Out:
# \begin{tabular}{llrrllrrrrrrrllrrrr}
# \toprule
# {} & Function &  Epochs &  Batch\_Size & Pooling &      Dropout &  FreqMean &  FreqStd &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Mean\_Accuracy &   Time &  Params \\
# \midrule
# 315  &      DHT &     500 &          10 &     Sum &   (0.2, 0.2) &       0.0 &    0.100 &       0.5 &       2 &        1 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &         0.0100 &           0.94 &  26.79 &   68356 \\
# 822  &      DHT &     500 &          10 &     Sum &   (0.2, 0.2) &       2.0 &    0.001 &       0.5 &       3 &        2 &       1 &           1 &       (1, 16, 16, 4) &      opt8 &         0.0040 &           0.90 &  19.89 &  102356 \\
# ...

# %% [markdown]
# ##### Evaluating all the subjects on the test set (retraining with train and val sets together) - not using yet

# %% [markdown]
# ###### DHT

# %%
dht_final = read_grid_search("results/final_35_DHT_top1_4")
dht_final.sort_values("Test_Accuracy", ascending=False)
# Out:
#     Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 14       31      DHT       0.5       3        2       1           1
# 27       13      DHT       0.5       3        2       1           1
# 6        22      DHT       0.5       3        2       1           1
# 24       32      DHT       0.5       3        2       1           1
# 32       26      DHT       0.5       3        2       1           1
# 16        8      DHT       0.5       3        2       1           1
# 2         4      DHT       0.5       3        2       1           1
# 3        35      DHT       0.5       3        2       1           1
# 4        20      DHT       0.5       3        2       1           1
# 22        1      DHT       0.5       3        2       1           1
# 10        5      DHT       0.5       3        2       1           1
# 8        16      DHT       0.5       3        2       1           1
# 18       14      DHT       0.5       3        2       1           1
# ...

# %%
dht_final.loc[:,"Test_Accuracy"].mean()
# Out:
# 0.7023809782857142

# %%
print(dht_final.sort_values("Test_Accuracy", ascending=False).to_latex())
# Out:
# \begin{tabular}{lrlrrrrrllrr}
# \toprule
# {} &  Subject & Function &  Time\_Off &  Window &  Overlap &  Levels &  Band\_Width & Neuron\_Configuration & Optimizer &  Learning\_Rate &  Test\_Accuracy \\
# \midrule
# 14 &       31 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 27 &       13 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 6  &       22 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 24 &       32 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# 32 &       26 &      DHT &       0.5 &       3 &        2 &       1 &           1 &               [8, 8] &      opt1 &           0.01 &       1.000000 \\
# ...

# %% [markdown]
# ### Check results - Visual MNIST of the Brain

# %% [markdown]
# ##### Binary MNIST

# %%
# here we classify digit and non-digit
dft_mnist = read_grid_search("results/mnist_1_DFT_2_kfold_1")
dft_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size      Dropout  FreqMean  FreqStd  Time_Off  \
# 86       DFT     500          10   (0.2, 0.2)       1.0    0.001       0.0
# 235      DFT     500          10  (0.3, 0.15)       1.0    0.001       0.0
# 51       DFT     500          10   (0.3, 0.5)       1.0    0.010       0.0
# 1        DFT     500          10   (0.3, 0.5)       0.0    0.010       0.0
# 105      DFT     500          10  (0.3, 0.15)       2.0    0.001       0.0
# 135      DFT     500          10   (0.5, 0.5)       1.0    0.010       0.0
# 82       DFT     500          10   (0.2, 0.2)       0.0    0.001       0.0
# 72       DFT     500          10   (0.5, 0.5)       2.0    0.001       0.0
# 239      DFT     500          10   (0.3, 0.5)       1.0    0.100       0.0
# 80       DFT     500          10   (0.6, 0.2)       0.0    0.100       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# ...

# %%
# here we classify digit and non-digit
dht_mnist = read_grid_search("results/mnist_1_DHT_2_kfold_1")
dht_mnist.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#     Function  Epochs  Batch_Size     Dropout  FreqMean  FreqStd  Time_Off  \
# 53       DHT     500          10  (0.6, 0.2)       1.0    0.010       0.0
# 217      DHT     500          10  (0.3, 0.5)       1.0    0.001       0.0
# 157      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 108      DHT     500          10  (0.2, 0.2)       1.0    0.001       0.0
# 15       DHT     500          10  (0.3, 0.5)       1.0    0.100       0.0
# 72       DHT     500          10  (0.2, 0.2)       1.0    0.100       0.0
# 60       DHT     500          10  (0.3, 0.5)       0.0    0.010       0.0
# 129      DHT     500          10  (0.6, 0.2)       1.0    0.001       0.0
# 187      DHT     500          10  (0.3, 0.5)       2.0    0.001       0.0
# 23       DHT     500          10  (0.2, 0.2)       2.0    0.010       0.0
#
#      Window  Overlap  Levels  Band_Width Neuron_Configuration Optimizer  \
# 53        2        0       3           2         (1, 4, 8, 2)      opt8
# ...

# %% [markdown]
# ### Check results - BCI Competition Dataset IV 2a

# %% [markdown]
# #### K-Fold DFT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
bcic2akfold1 = read_grid_search("results_v3/bcic2a_1_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold1.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 2146      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 363       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1754      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1223      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 2236      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 1216      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 69        DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 810       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 2090      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 237       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 2146       0.0       5        0       3           1       (1, 16, 32, 4)
# ...

# %%
bcic2akfold1.shape[0]
# Out:
# 2316

# %% [markdown]
# ##### Subject 2

# %%
bcic2akfold2 = read_grid_search("results_v3/bcic2a_2_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold2.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 495       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1484      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 712       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 581       DFT     500          10     Sum   (0.2, 0.2)       2.0    0.001
# 649       DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 964       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 592       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 951       DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 699       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 681       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 495        0.0       5        0       2           3       (1, 16, 32, 4)
# ...

# %%
bcic2akfold2.shape[0]
# Out:
# 2198

# %% [markdown]
# ##### Subject 3

# %%
bcic2akfold3 = read_grid_search("results_v3/bcic2a_3_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold3.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 726       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.001
# 1128      DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 1647      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 1729      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1520      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2081      DFT     500          10     Sum  (0.3, 0.15)       2.0    0.010
# 111       DFT     500          10     Sum   (0.3, 0.5)       1.0    0.001
# 516       DFT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 1340      DFT     500          10     Sum   (0.3, 0.5)       2.0    0.100
# 218       DFT     500          10     Sum   (0.2, 0.2)       1.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 726        0.5       5        0       3           4       (1, 16, 16, 4)
# ...

# %%
bcic2akfold3.shape[0]
# Out:
# 2197

# %% [markdown]
# ##### Subject 4

# %%
bcic2akfold4 = read_grid_search("results_v3/bcic2a_4_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 327       DFT     500          10     Sum  (0.3, 0.5)       0.0    0.001
# 731       DFT     500          10     Sum  (0.5, 0.5)       0.0    0.100
# 1940      DFT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 1553      DFT     500          10     Sum  (0.3, 0.5)       0.0    0.001
# 620       DFT     500          10     Sum  (0.2, 0.2)       1.0    0.001
# 1017      DFT     500          10     Sum  (0.6, 0.2)       1.0    0.001
# 1659      DFT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 406       DFT     500          10     Sum  (0.2, 0.2)       2.0    0.001
# 1280      DFT     500          10     Sum  (0.5, 0.5)       0.0    0.100
# 898       DFT     500          10     Sum  (0.2, 0.2)       1.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 327        0.5       5        0       3           5       (1, 16, 16, 4)
# ...

# %%
bcic2akfold4.shape[0]
# Out:
# 2313

# %% [markdown]
# ##### Subject 5

# %%
bcic2akfold5 = read_grid_search("results_v3/bcic2a_5_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold5.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 981       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 1464      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 605       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 2000      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1705      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 1729      DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 315       DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 389       DFT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1176      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 1376      DFT     500          10     Sum   (0.2, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 981        0.0       5        0       2           4       (1, 16, 32, 4)
# ...

# %%
bcic2akfold5.shape[0]
# Out:
# 2164

# %% [markdown]
# #####  Subject 6

# %%
bcic2akfold6 = read_grid_search("results_v3/bcic2a_6_DFT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold6.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 374       DFT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 1352      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 2011      DFT     500          10     Sum  (0.3, 0.15)       0.0    0.010
# 193       DFT     500          10     Sum   (0.2, 0.2)       1.0    0.001
# 1743      DFT     500          10     Sum   (0.6, 0.2)       1.0    0.001
# 1331      DFT     500          10     Sum   (0.6, 0.2)       2.0    0.010
# 314       DFT     500          10     Sum   (0.2, 0.2)       1.0    0.010
# 1624      DFT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 931       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
# 409       DFT     500          10     Sum   (0.2, 0.2)       0.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 374        0.5       5        0       2           5       (1, 16, 16, 4)
# ...

# %%
bcic2akfold6.shape[0]
# Out:
# 2164

# %% [markdown]
# #### K-Fold DHT (1 subject)

# %% [markdown]
# ##### Subject 1

# %%
bcic2akfold1 = read_grid_search("results_v3/bcic2a_1_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold1.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1258      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 772       DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1336      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 564       DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 2076      DHT     500          10     Sum   (0.2, 0.2)       2.0    0.100
# 1358      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 1445      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 304       DHT     500          10     Sum   (0.6, 0.2)       0.0    0.100
# 2089      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 1552      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1258       0.5       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2akfold1.shape[0]
# Out:
# 2338

# %% [markdown]
# ##### Subject 2

# %%
bcic2akfold2 = read_grid_search("results_v3/bcic2a_2_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold2.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1033      DHT     500          10     Sum   (0.5, 0.5)       0.0    0.100
# 1586      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 936       DHT     500          10     Sum   (0.2, 0.2)       0.0    0.001
# 1355      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 1885      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.001
# 1467      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.001
# 1221      DHT     500          10     Sum  (0.3, 0.15)       0.0    0.100
# 1351      DHT     500          10     Sum   (0.6, 0.2)       1.0    0.100
# 1594      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.001
# 412       DHT     500          10     Sum  (0.3, 0.15)       2.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1033       0.0       5        0       2           3       (1, 16, 32, 4)
# ...

# %%
bcic2akfold2.shape[0]
# Out:
# 2170

# %% [markdown]
# ##### Subject 3

# %%
bcic2akfold3 = read_grid_search("results_v3/bcic2a_3_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold3.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 49        DHT     500          10     Sum  (0.2, 0.2)       0.0    0.010
# 1327      DHT     500          10     Sum  (0.3, 0.5)       1.0    0.010
# 39        DHT     500          10     Sum  (0.6, 0.2)       2.0    0.100
# 1827      DHT     500          10     Sum  (0.5, 0.5)       1.0    0.001
# 1752      DHT     500          10     Sum  (0.5, 0.5)       0.0    0.001
# 823       DHT     500          10     Sum  (0.3, 0.5)       2.0    0.001
# 126       DHT     500          10     Sum  (0.2, 0.2)       2.0    0.100
# 841       DHT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 1441      DHT     500          10     Sum  (0.6, 0.2)       1.0    0.100
# 277       DHT     500          10     Sum  (0.5, 0.5)       2.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 49         0.0       5        0       2           3       (1, 16, 16, 4)
# ...

# %%
bcic2akfold3.shape[0]
# Out:
# 2170

# %% [markdown]
# ##### Subject 4

# %%
bcic2akfold4 = read_grid_search("results_v3/bcic2a_4_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold4.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling      Dropout  FreqMean  FreqStd  \
# 1905      DHT     500          10     Sum   (0.2, 0.2)       0.0    0.010
# 947       DHT     500          10     Sum   (0.5, 0.5)       0.0    0.010
# 1959      DHT     500          10     Sum   (0.3, 0.5)       0.0    0.010
# 1859      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
# 726       DHT     500          10     Sum  (0.3, 0.15)       2.0    0.001
# 558       DHT     500          10     Sum   (0.3, 0.5)       0.0    0.001
# 2283      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.001
# 2259      DHT     500          10     Sum   (0.3, 0.5)       1.0    0.010
# 856       DHT     500          10     Sum  (0.3, 0.15)       2.0    0.100
# 1318      DHT     500          10     Sum   (0.6, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1905       0.0       5        0       2           5       (1, 16, 32, 4)
# ...

# %%
bcic2akfold4.shape[0]
# Out:
# 2338

# %% [markdown]
# ##### Subject 5

# %%
bcic2akfold5 = read_grid_search("results_v3/bcic2a_5_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold5.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 1683      DHT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 52        DHT     500          10     Sum  (0.6, 0.2)       0.0    0.010
# 785       DHT     500          10     Sum  (0.5, 0.5)       0.0    0.010
# 1924      DHT     500          10     Sum  (0.6, 0.2)       0.0    0.100
# 374       DHT     500          10     Sum  (0.6, 0.2)       0.0    0.100
# 655       DHT     500          10     Sum  (0.2, 0.2)       0.0    0.001
# 1036      DHT     500          10     Sum  (0.2, 0.2)       0.0    0.010
# 1989      DHT     500          10     Sum  (0.6, 0.2)       0.0    0.001
# 891       DHT     500          10     Sum  (0.2, 0.2)       0.0    0.100
# 603       DHT     500          10     Sum  (0.2, 0.2)       0.0    0.010
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 1683       0.0       5        0       3           4       (1, 16, 16, 4)
# ...

# %%
bcic2akfold5.shape[0]
# Out:
# 2170

# %% [markdown]
# ##### Subject 6

# %%
bcic2akfold6 = read_grid_search("results_v3/bcic2a_6_DHT_4_Sum_kfold_1") #bcic2a_grid_search_{len(subjects)}_{f}_{n_classes}_kfold
bcic2akfold6.sort_values("Mean_Accuracy",ascending=False).head(10)
# Out:
#      Function  Epochs  Batch_Size Pooling     Dropout  FreqMean  FreqStd  \
# 552       DHT     500          10     Sum  (0.6, 0.2)       2.0    0.100
# 1186      DHT     500          10     Sum  (0.6, 0.2)       2.0    0.001
# 1654      DHT     500          10     Sum  (0.2, 0.2)       0.0    0.001
# 1350      DHT     500          10     Sum  (0.6, 0.2)       1.0    0.100
# 1546      DHT     500          10     Sum  (0.3, 0.5)       2.0    0.100
# 217       DHT     500          10     Sum  (0.6, 0.2)       0.0    0.010
# 1921      DHT     500          10     Sum  (0.2, 0.2)       1.0    0.100
# 123       DHT     500          10     Sum  (0.3, 0.5)       0.0    0.010
# 1775      DHT     500          10     Sum  (0.6, 0.2)       1.0    0.100
# 54        DHT     500          10     Sum  (0.2, 0.2)       0.0    0.100
#
#       Time_Off  Window  Overlap  Levels  Band_Width Neuron_Configuration  \
# 552        0.5       5        0       3           3       (1, 16, 32, 4)
# ...

# %%
bcic2akfold6.shape[0]
# Out:
# 2170

# %% [markdown]
# ##### Final training with best config - not using yet

# %%
#### Classification using DHT and no validation set (training and evaluating on the test set)
bcic2a = read_grid_search("results/final_bcic2a_1_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        1      DHT       0.0       5        0       3           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt3          0.001       0.600695

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DHT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        8      DHT       0.0       5        0       3           5
# 6        3      DHT       0.0       5        0       3           5
# 7        9      DHT       0.0       5        0       3           5
# 2        1      DHT       0.0       5        0       3           5
# 8        4      DHT       0.0       5        0       3           5
# 3        2      DHT       0.0       5        0       3           5
# 5        7      DHT       0.0       5        0       3           5
# 1        6      DHT       0.0       5        0       3           5
# 4        5      DHT       0.0       5        0       3           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt3          0.001       0.704861
# 6             [64, 64]      opt3          0.001       0.697917
# 7             [64, 64]      opt3          0.001       0.604167
# ...

# %%
bcic2a = read_grid_search("results/final_bcic2a_1_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 0        1      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 0             [64, 64]      opt8          0.001          0.625

# %%
bcic2a = read_grid_search("results/final_bcic2a_9_DFT_top10_4")
bcic2a.sort_values("Test_Accuracy",ascending=False).head(10)
# Out:
#    Subject Function  Time_Off  Window  Overlap  Levels  Band_Width  \
# 5        8      DFT       0.0       5        0       2           5
# 1        9      DFT       0.0       5        0       2           5
# 3        3      DFT       0.0       5        0       2           5
# 4        1      DFT       0.0       5        0       2           5
# 7        4      DFT       0.0       5        0       2           5
# 6        2      DFT       0.0       5        0       2           5
# 8        7      DFT       0.0       5        0       2           5
# 0        6      DFT       0.0       5        0       2           5
# 2        5      DFT       0.0       5        0       2           5
#
#   Neuron_Configuration Optimizer  Learning_Rate  Test_Accuracy
# 5             [64, 64]      opt8          0.001       0.697917
# 1             [64, 64]      opt8          0.001       0.687500
# 3             [64, 64]      opt8          0.001       0.687500
# ...
